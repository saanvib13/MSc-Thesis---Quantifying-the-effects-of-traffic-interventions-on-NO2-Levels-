# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv("../mydata/datasets_for_model/GP_rolling_window_changepoints_NO2_entire.csv")
df["Start"] = pd.to_datetime(df["Start"])
df["Start"] = df["Start"].dt.tz_localize("Europe/Dublin") 

print(len(df))

# Sort by timestamp
changepoints_sorted = df["Start"].sort_values().reset_index(drop=True)

# Set threshold for merging (you can change this to 6h, 12h, 24h etc.)
threshold = pd.Timedelta(hours=1)

clusters = []  # list to store clusters of close changepoints
current_cluster = [changepoints_sorted[0]]

# Group changepoints into clusters based on the threshold
for cp in changepoints_sorted[1:]:
    if cp - current_cluster[-1] <= threshold:
        current_cluster.append(cp)
    else:
        clusters.append(current_cluster)
        current_cluster = [cp]
clusters.append(current_cluster)  # add the last cluster

# For each cluster, choose the final timestamp
# Options: min (earliest), max (latest), or median (middle)
final_changepoints = [pd.Series(cluster).median() for cluster in clusters]

# Create final DataFrame
final_cp_df = pd.DataFrame({"Final_Changepoints": final_changepoints})

# Save to CSV if needed
final_cp_df.to_csv("final_changepoints.csv", index=False)

print(final_cp_df)
print(f"Total final changepoints: {len(final_cp_df)}")
# Out:
# 200
#            Final_Changepoints
# 0   2023-08-06 18:00:00+01:00
# 1   2023-08-11 18:00:00+01:00
# 2   2023-08-16 16:00:00+01:00
# 3   2023-08-16 18:00:00+01:00
# 4   2023-08-18 15:00:00+01:00
# ..                        ...
# 154 2024-06-16 00:00:00+01:00
# 155 2024-06-21 00:00:00+01:00
# 156 2024-06-26 00:00:00+01:00
# 157 2024-06-28 14:30:00+01:00
# 158 2024-06-29 00:00:00+01:00
#
# [159 rows x 1 columns]
# Total final changepoints: 159

# %%
df.head()
# Out:
#    Unnamed: 0         Window_Start           Window_End  Segment  \
# 0           1  2023-08-06 18:00:00  2023-08-16 18:00:00        1
# 1           2  2023-08-11 18:00:00  2023-08-21 18:00:00        1
# 2           3  2023-08-11 18:00:00  2023-08-21 18:00:00        2
# 3           4  2023-08-11 18:00:00  2023-08-21 18:00:00        3
# 4           5  2023-08-16 18:00:00  2023-08-26 18:00:00        1
#
#                       Start                  End       Mean     CI_low  \
# 0 2023-08-06 18:00:00+01:00  2023-08-16 17:00:00   8.926203   8.404168
# 1 2023-08-11 18:00:00+01:00  2023-08-16 15:00:00   8.591655   7.871712
# 2 2023-08-16 16:00:00+01:00  2023-08-18 14:00:00  16.354886  14.702395
# 3 2023-08-18 15:00:00+01:00  2023-08-21 17:00:00   6.985233   6.111929
# 4 2023-08-16 18:00:00+01:00  2023-08-18 14:00:00  16.219467  14.601717
#
#      CI_high mean_CI_nonoverlap  MergeGroup
# 0   9.493710                NaN           1
# 1   9.267392                NaN           1
# 2  18.001092               True           2
# 3   7.998340               True           3
# 4  17.753730                NaN           1

# %%
df = pd.read_csv("../mydata/datasets_for_model/cleaned/GP_cleaned.csv")
df.tail()
# Out:
#       Unnamed: 0         Timestamp  counter.1  counter.2  rain  temp  wetb  \
# 6215        6216  30-06-2024 19:00        467     1443.0   0.0  14.4 -49.0
# 6216        6217  30-06-2024 20:00        331     1099.0   0.0  13.2 -49.0
# 6217        6218  30-06-2024 21:00        246      737.0   0.2  12.2 -49.0
# 6218        6219  30-06-2024 22:00        152      576.0   0.1  11.9 -49.0
# 6219        6220  30-06-2024 23:00        131      349.0   0.0  12.1 -49.0
#
#       dewpt  vappr  rhum  ...  wddir  ww   w  sun    vis  clht  clamt  \
# 6215    9.1   11.6    71  ...    290  60  62  0.0  40000    70      7
# 6216    9.9   12.2    80  ...    320  60  62  0.0  35000    60      7
# 6217   10.5   12.7    89  ...    290  21  62  0.0  35000    60      7
# 6218   10.1   12.4    89  ...    300  60  62  0.0  30000    12      7
# 6219   10.1   12.4    88  ...    300  21  62  0.0  30000    50      7
#
#             NO2        date  hour
# 6215  13.420667  30-06-2024    19
# 6216  15.303667  30-06-2024    20
# 6217  12.910333  30-06-2024    21
# 6218  11.412000  30-06-2024    22
# 6219   7.827000  30-06-2024    23
#
# [5 rows x 22 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.utils import resample

# Load final changepoints and full NO2 dataset
final_cp = pd.read_csv("final_changepoints.csv")
final_cp["Final_Changepoints"] = pd.to_datetime(final_cp["Final_Changepoints"], utc=True)
final_cp["Final_Changepoints"] = final_cp["Final_Changepoints"].dt.tz_convert("Europe/Dublin") 


df = pd.read_csv("../mydata/datasets_for_model/cleaned/GP_cleaned.csv")
df["Timestamp"] = pd.to_datetime(df["Timestamp"], format='%d-%m-%Y %H:%M')
df["Timestamp"] = df["Timestamp"].dt.tz_localize("Europe/Dublin") 
df = df.sort_values("Timestamp")
# Ensure changepoints are sorted
final_cp = final_cp.sort_values("Final_Changepoints").reset_index(drop=True)

# %%
df.tail()
# Out:
#       Unnamed: 0                 Timestamp  counter.1  counter.2  rain  temp  \
# 6215        6216 2024-06-30 19:00:00+01:00        467     1443.0   0.0  14.4
# 6216        6217 2024-06-30 20:00:00+01:00        331     1099.0   0.0  13.2
# 6217        6218 2024-06-30 21:00:00+01:00        246      737.0   0.2  12.2
# 6218        6219 2024-06-30 22:00:00+01:00        152      576.0   0.1  11.9
# 6219        6220 2024-06-30 23:00:00+01:00        131      349.0   0.0  12.1
#
#       wetb  dewpt  vappr  rhum  ...  wddir  ww   w  sun    vis  clht  clamt  \
# 6215 -49.0    9.1   11.6    71  ...    290  60  62  0.0  40000    70      7
# 6216 -49.0    9.9   12.2    80  ...    320  60  62  0.0  35000    60      7
# 6217 -49.0   10.5   12.7    89  ...    290  21  62  0.0  35000    60      7
# 6218 -49.0   10.1   12.4    89  ...    300  60  62  0.0  30000    12      7
# 6219 -49.0   10.1   12.4    88  ...    300  21  62  0.0  30000    50      7
#
#             NO2        date  hour
# 6215  13.420667  30-06-2024    19
# 6216  15.303667  30-06-2024    20
# 6217  12.910333  30-06-2024    21
# 6218  11.412000  30-06-2024    22
# 6219   7.827000  30-06-2024    23
#
# [5 rows x 22 columns]

# %%
all_cps = [df["Timestamp"].min()] + final_cp["Final_Changepoints"].tolist()[1:-1] + [df["Timestamp"].max()]
all_cps
# Out:
# [Timestamp('2023-08-06 18:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-08-11 18:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-08-16 16:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-08-16 18:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-08-18 15:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-08-21 18:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-08-22 15:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-08-23 05:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-08-23 10:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-08-23 19:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-08-23 21:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-08-26 18:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-08-31 18:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-09-03 15:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-09-05 18:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-09-09 23:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-09-10 18:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-09-12 05:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-09-12 18:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-09-15 18:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-09-16 21:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-09-17 21:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-09-20 17:30:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-09-23 09:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-09-23 11:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-09-23 15:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-09-23 21:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-09-25 18:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-09-26 05:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-09-30 18:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-10-03 07:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-10-03 10:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-10-05 18:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-10-07 16:30:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-10-10 08:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-10-10 10:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-10-10 18:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-10-11 05:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-10-11 09:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-10-14 17:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-10-15 18:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-10-20 18:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-10-23 06:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-10-25 18:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2023-10-30 18:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2023-11-01 14:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2023-11-01 18:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2023-11-02 15:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2023-11-04 18:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2023-11-09 18:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2023-11-14 05:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2023-11-14 08:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2023-11-14 10:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2023-11-14 18:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2023-12-16 00:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2023-12-18 06:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2023-12-21 00:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2023-12-26 00:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2023-12-26 07:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2023-12-26 16:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2023-12-26 19:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2023-12-29 15:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2023-12-29 23:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2023-12-30 01:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2023-12-31 00:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-01-02 05:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-01-02 07:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-01-05 00:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-02-02 00:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-02-04 21:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-02-07 00:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-02-07 06:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-02-08 19:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-02-10 10:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-02-11 15:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-02-12 00:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-02-13 03:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-02-13 13:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-02-13 16:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-02-15 15:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-02-17 00:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-02-20 16:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-02-20 19:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-02-22 00:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-02-24 16:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-02-24 21:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-02-27 00:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-02-27 18:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-02-28 08:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-03-07 00:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-03-08 00:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-03-09 09:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-03-09 12:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-03-09 14:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-03-11 05:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-03-11 08:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-03-11 10:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-03-11 18:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-03-11 21:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-03-13 00:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-03-15 16:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-03-15 20:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-03-16 08:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-03-18 00:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-03-19 15:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-03-28 00:00:00+0000', tz='Europe/Dublin'),
#  Timestamp('2024-04-02 00:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-04-02 04:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-04-02 18:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-04-03 15:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-04-04 17:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-04-04 19:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-04-04 22:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-04-06 22:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-04-07 00:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-04-12 00:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-04-13 18:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-04-14 03:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-04-17 00:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-04-22 00:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-04-25 09:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-04-26 04:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-04-26 17:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-04-27 00:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-04-27 12:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-04-27 14:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-04-30 04:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-04-30 10:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-04-30 12:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-05-02 00:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-05-05 22:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-05-07 00:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-05-08 03:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-05-12 00:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-05-12 23:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-05-15 17:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-05-16 12:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-05-16 19:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-05-17 00:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-05-19 13:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-05-21 18:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-05-22 00:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-05-24 19:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-05-24 21:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-05-25 22:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-05-26 23:30:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-06-01 00:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-06-01 18:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-06-01 22:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-06-06 00:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-06-11 00:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-06-14 12:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-06-14 14:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-06-14 17:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-06-16 00:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-06-21 00:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-06-26 00:00:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-06-28 14:30:00+0100', tz='Europe/Dublin'),
#  Timestamp('2024-06-30 23:00:00+0100', tz='Europe/Dublin')]

# %%
# Add start & end bounds
all_cps = [df["Timestamp"].min()] + final_cp["Final_Changepoints"].tolist()[1:-1] + [df["Timestamp"].max()]

segment_stats = []

for i in range(len(all_cps)-1):
    seg_data = df[(df["Timestamp"] >= all_cps[i]) & (df["Timestamp"] < all_cps[i+1])]["NO2"].dropna()

    if len(seg_data) == 0:
        continue

    # Bootstrap mean
    boot_means = []
    for _ in range(500):  # 500 resamples
        sample = resample(seg_data)
        boot_means.append(sample.mean())

    ci_low = np.percentile(boot_means, 2.5)
    ci_high = np.percentile(boot_means, 97.5)

    segment_stats.append({
        "Segment": i+1,
        "Start": all_cps[i],
        "End": all_cps[i+1],
        "Mean_NO2": seg_data.mean(),
        "CI_low": ci_low,
        "CI_high": ci_high
    })

segment_df = pd.DataFrame(segment_stats)

# Check if adjacent segments overlap
segment_df["Overlap_with_prev"] = [np.nan] + [
    not (segment_df.iloc[i]["CI_low"] > segment_df.iloc[i-1]["CI_high"] or
         segment_df.iloc[i-1]["CI_low"] > segment_df.iloc[i]["CI_high"])
    for i in range(1, len(segment_df))
]

segment_df.to_csv("final_segments_with_bootstrap.csv", index=False)
print(segment_df.head())
# Out:
#    Segment                     Start                       End   Mean_NO2  \
# 0        1 2023-08-06 18:00:00+01:00 2023-08-11 18:00:00+01:00   9.080582
# 1        2 2023-08-11 18:00:00+01:00 2023-08-16 16:00:00+01:00   8.591655
# 2        3 2023-08-16 16:00:00+01:00 2023-08-16 18:00:00+01:00  19.401833
# 3        4 2023-08-16 18:00:00+01:00 2023-08-18 15:00:00+01:00  16.219467
# 4        5 2023-08-18 15:00:00+01:00 2023-08-21 18:00:00+01:00   6.985233
#
#       CI_low    CI_high Overlap_with_prev
# 0   8.162900   9.938886               NaN
# 1   7.879322   9.288494              True
# 2  17.613667  21.190000             False
# 3  14.569792  17.975119              True
# 4   6.257935   7.882766             False

# %%
segment_df.head(10)
# Out:
#    Segment                     Start                       End   Mean_NO2  \
# 0        1 2023-08-06 18:00:00+01:00 2023-08-11 18:00:00+01:00   9.080582
# 1        2 2023-08-11 18:00:00+01:00 2023-08-16 16:00:00+01:00   8.591655
# 2        3 2023-08-16 16:00:00+01:00 2023-08-16 18:00:00+01:00  19.401833
# 3        4 2023-08-16 18:00:00+01:00 2023-08-18 15:00:00+01:00  16.219467
# 4        5 2023-08-18 15:00:00+01:00 2023-08-21 18:00:00+01:00   6.985233
# 5        6 2023-08-21 18:00:00+01:00 2023-08-22 15:00:00+01:00   7.328587
# 6        7 2023-08-22 15:00:00+01:00 2023-08-23 05:00:00+01:00  10.784786
# 7        8 2023-08-23 05:00:00+01:00 2023-08-23 10:00:00+01:00  24.987400
# 8        9 2023-08-23 10:00:00+01:00 2023-08-23 19:00:00+01:00   9.025370
# 9       10 2023-08-23 19:00:00+01:00 2023-08-23 21:00:00+01:00   9.489167
#
#       CI_low    CI_high Overlap_with_prev
# 0   8.162900   9.938886               NaN
# 1   7.879322   9.288494              True
# 2  17.613667  21.190000             False
# 3  14.569792  17.975119              True
# 4   6.257935   7.882766             False
# 5   6.102139   8.745760              True
# 6   9.298120  12.393558             False
# 7  18.102933  29.600467             False
# 8   5.268032  13.945760             False
# 9   5.960000  13.018333              True

# %%
import pandas as pd

merged_segments = []
for i, row in segment_df.iterrows():
    if i == 0:
        merged_segments.append(row.to_dict())
    else:
        prev = merged_segments[-1]

        if str(row["Overlap_with_prev"]) == "True":
            # Merge with previous segment
            new_entry = {
                "Segment": prev["Segment"],  # keep previous segment number
                "Start": prev["Start"],
                "End": row["End"],
                # Weighted mean using segment durations
                "Mean_NO2": (prev["Mean_NO2"] + row["Mean_NO2"]) / 2,
                "CI_low": min(prev["CI_low"], row["CI_low"]),
                "CI_high": max(prev["CI_high"], row["CI_high"]),
                "Overlap_with_prev": False
            }
            merged_segments[-1] = new_entry  # replace previous entry
        else:
            merged_segments.append(row.to_dict())

merged_df = pd.DataFrame(merged_segments)
merged_df.to_csv("GP/full_merged_final_segments.csv", index=False)
print(merged_df.head())
# Out:
#    Segment                     Start                       End   Mean_NO2  \
# 0        1 2023-08-06 18:00:00+01:00 2023-08-16 16:00:00+01:00   8.836119
# 1        3 2023-08-16 16:00:00+01:00 2023-08-18 15:00:00+01:00  17.810650
# 2        5 2023-08-18 15:00:00+01:00 2023-08-22 15:00:00+01:00   7.156910
# 3        7 2023-08-22 15:00:00+01:00 2023-08-23 05:00:00+01:00  10.784786
# 4        8 2023-08-23 05:00:00+01:00 2023-08-23 10:00:00+01:00  24.987400
#
#       CI_low    CI_high  Overlap_with_prev
# 0   7.879322   9.938886              False
# 1  14.569792  21.190000              False
# 2   6.102139   8.745760              False
# 3   9.298120  12.393558              False
# 4  18.102933  29.600467              False

# %%
len(merged_df)
# Out:
# 146

# %%
merged_df.head()
# Out:
#    Segment                     Start                       End   Mean_NO2  \
# 0        1 2023-01-01 00:00:00+00:00 2023-01-16 00:00:00+00:00  30.578458
# 1        2 2023-01-16 00:00:00+00:00 2023-02-12 00:00:00+00:00  42.397236
# 2        5 2023-02-12 00:00:00+00:00 2023-02-26 00:00:00+00:00  25.979296
# 3        7 2023-02-26 00:00:00+00:00 2023-03-11 23:30:00+00:00  32.114651
# 4        9 2023-03-11 23:30:00+00:00 2023-03-26 00:00:00+00:00  25.311875
#
#       CI_low    CI_high Overlap_with_prev
# 0  28.698123  32.613665               NaN
# 1  36.056039  51.510518             False
# 2  23.797948  28.090957             False
# 3  29.636493  35.454993             False
# 4  23.764761  26.797289             False

# %%
df.tail()
# Out:
#       Unnamed: 0                 Timestamp  counter.1  counter.2  rain  temp  \
# 6215        6216 2024-06-30 19:00:00+01:00        467     1443.0   0.0  14.4
# 6216        6217 2024-06-30 20:00:00+01:00        331     1099.0   0.0  13.2
# 6217        6218 2024-06-30 21:00:00+01:00        246      737.0   0.2  12.2
# 6218        6219 2024-06-30 22:00:00+01:00        152      576.0   0.1  11.9
# 6219        6220 2024-06-30 23:00:00+01:00        131      349.0   0.0  12.1
#
#       wetb  dewpt  vappr  rhum  ...  wddir  ww   w  sun    vis  clht  clamt  \
# 6215 -49.0    9.1   11.6    71  ...    290  60  62  0.0  40000    70      7
# 6216 -49.0    9.9   12.2    80  ...    320  60  62  0.0  35000    60      7
# 6217 -49.0   10.5   12.7    89  ...    290  21  62  0.0  35000    60      7
# 6218 -49.0   10.1   12.4    89  ...    300  60  62  0.0  30000    12      7
# 6219 -49.0   10.1   12.4    88  ...    300  21  62  0.0  30000    50      7
#
#             NO2        date  hour
# 6215  13.420667  30-06-2024    19
# 6216  15.303667  30-06-2024    20
# 6217  12.910333  30-06-2024    21
# 6218  11.412000  30-06-2024    22
# 6219   7.827000  30-06-2024    23
#
# [5 rows x 22 columns]
