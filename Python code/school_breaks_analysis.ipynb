# %%
import pandas as pd
# mid_term=pd.read_csv('../mydata/school_terms_analysis/traffic_Oct_MTB.csv')
# week_bef_MT=pd.read_csv('../mydata/school_terms_analysis/traffic_Oct_MTB_1w_bef.csv')
# week_aft_MT=pd.read_csv('../mydata/school_terms_analysis/traffic_Oct_MTB_1w_aft.csv')

# %%
traffic=pd.read_csv('../mydata/traffic/combined_traffic_ct_1_2_2023-24.csv')
traffic.head()
# Out:
#    Unnamed: 0                  Timestamp  counter 1  counter 2
# 0           0  2023-01-01 00:00:00+00:00      151.0      496.0
# 1           1  2023-01-01 01:00:00+00:00      219.0      503.0
# 2           2  2023-01-01 02:00:00+00:00      180.0      409.0
# 3           3  2023-01-01 03:00:00+00:00      137.0      330.0
# 4           4  2023-01-01 04:00:00+00:00       53.0      143.0

# %%
traffic.drop(columns=[traffic.columns[0]], axis=1, inplace=True)
traffic['date']=pd.to_datetime(traffic['Timestamp'], utc=True).dt.date
oct_mt_2023=traffic[(traffic['date']>=pd.to_datetime('2023-10-30').date()) & (traffic['date']<=pd.to_datetime('2023-11-03').date())]
oct_mt_2024=traffic[(traffic['date']>=pd.to_datetime('2024-10-28').date()) & (traffic['date']<=pd.to_datetime('2024-11-01').date())]

oct_mt_2023_wb=traffic[(traffic['date']>=pd.to_datetime('2023-10-23').date()) & (traffic['date']<=pd.to_datetime('2023-10-27').date())]
oct_mt_2023_wa=traffic[(traffic['date']>=pd.to_datetime('2023-11-06').date()) & (traffic['date']<=pd.to_datetime('2023-11-10').date())]

oct_mt_2024_wb=traffic[(traffic['date']>=pd.to_datetime('2024-10-24').date()) & (traffic['date']<=pd.to_datetime('2024-10-28').date())]
oct_mt_2024_wa=traffic[(traffic['date']>=pd.to_datetime('2024-11-07').date()) & (traffic['date']<=pd.to_datetime('2024-11-11').date())]


feb_mt_2023=traffic[(traffic['date']>=pd.to_datetime('2023-02-13').date()) & (traffic['date']<=pd.to_datetime('2023-02-17').date())]
feb_mt_2024=traffic[(traffic['date']>=pd.to_datetime('2024-02-12').date()) & (traffic['date']<=pd.to_datetime('2024-02-16').date())]

feb_mt_2023_wb=traffic[(traffic['date']>=pd.to_datetime('2023-01-30').date()) & (traffic['date']<=pd.to_datetime('2023-02-03').date())]
feb_mt_2023_wa=traffic[(traffic['date']>=pd.to_datetime('2023-02-20').date()) & (traffic['date']<=pd.to_datetime('2023-02-24').date())]

feb_mt_2024_wb=traffic[(traffic['date']>=pd.to_datetime('2024-01-29').date()) & (traffic['date']<=pd.to_datetime('2024-02-02').date())]
feb_mt_2024_wa=traffic[(traffic['date']>=pd.to_datetime('2024-02-19').date()) & (traffic['date']<=pd.to_datetime('2024-02-23').date())]

# %%
oct_mt_2023.reset_index(inplace=True)
oct_mt_2024.reset_index(inplace=True)
oct_mt_2023_wb.reset_index(inplace=True)
oct_mt_2023_wa.reset_index(inplace=True)
oct_mt_2024_wb.reset_index(inplace=True)
oct_mt_2024_wa.reset_index(inplace=True)

feb_mt_2023.reset_index(inplace=True)
feb_mt_2024.reset_index(inplace=True)
feb_mt_2023_wb.reset_index(inplace=True)
feb_mt_2023_wa.reset_index(inplace=True)
feb_mt_2024_wb.reset_index(inplace=True)
feb_mt_2024_wa.reset_index(inplace=True)

# %%
oct_mt_2023.drop(columns=['index'], axis=1, inplace=True)
oct_mt_2024.drop(columns=['index'], axis=1, inplace=True)
oct_mt_2023_wb.drop(columns=['index'], axis=1, inplace=True)
oct_mt_2023_wa.drop(columns=['index'], axis=1, inplace=True)
oct_mt_2024_wb.drop(columns=['index'], axis=1, inplace=True)
oct_mt_2024_wa.drop(columns=['index'], axis=1, inplace=True)

feb_mt_2023.drop(columns=['index'], axis=1, inplace=True)
feb_mt_2024.drop(columns=['index'], axis=1, inplace=True)
feb_mt_2023_wb.drop(columns=['index'], axis=1, inplace=True)
feb_mt_2023_wa.drop(columns=['index'], axis=1, inplace=True)
feb_mt_2024_wb.drop(columns=['index'], axis=1, inplace=True)
feb_mt_2024_wa.drop(columns=['index'], axis=1, inplace=True)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1389640\949940710.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oct_mt_2023.drop(columns=['index'], axis=1, inplace=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1389640\949940710.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oct_mt_2024.drop(columns=['index'], axis=1, inplace=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1389640\949940710.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
oct_mt_2024_wb
# Out:
#                      Timestamp  counter 1  counter 2        date
# 0    2024-10-24 01:00:00+01:00       42.0      309.0  2024-10-24
# 1    2024-10-24 02:00:00+01:00       23.0      236.0  2024-10-24
# 2    2024-10-24 03:00:00+01:00       25.0      232.0  2024-10-24
# 3    2024-10-24 04:00:00+01:00       25.0      223.0  2024-10-24
# 4    2024-10-24 05:00:00+01:00       59.0      457.0  2024-10-24
# ..                         ...        ...        ...         ...
# 115  2024-10-28 19:00:00+00:00      402.0     1360.0  2024-10-28
# 116  2024-10-28 20:00:00+00:00      290.0      970.0  2024-10-28
# 117  2024-10-28 21:00:00+00:00      200.0      714.0  2024-10-28
# 118  2024-10-28 22:00:00+00:00      133.0      425.0  2024-10-28
# 119  2024-10-28 23:00:00+00:00       96.0      313.0  2024-10-28
#
# [120 rows x 4 columns]

# %%
feb_mt_2023.head()
# Out:
#                    Timestamp  counter 1  counter 2        date
# 0  2023-02-13 00:00:00+00:00       73.0      236.0  2023-02-13
# 1  2023-02-13 01:00:00+00:00       73.0      135.0  2023-02-13
# 2  2023-02-13 02:00:00+00:00       70.0      129.0  2023-02-13
# 3  2023-02-13 03:00:00+00:00       39.0      118.0  2023-02-13
# 4  2023-02-13 04:00:00+00:00       23.0      169.0  2023-02-13

# %%
feb_mt_2023['hour']=pd.to_datetime(feb_mt_2023['Timestamp'],utc=True).dt.hour
feb_mt_2023_wb['hour']=pd.to_datetime(feb_mt_2023_wb['Timestamp'],utc=True).dt.hour
feb_mt_2023_wa['hour']=pd.to_datetime(feb_mt_2023_wa['Timestamp'],utc=True).dt.hour


mid_term=pd.DataFrame({
    'hour':feb_mt_2023['hour'],
    'counter 1': (feb_mt_2023['counter 1'] + feb_mt_2024['counter 1'])/2,
    'counter 2': (feb_mt_2023['counter 2'] + feb_mt_2024['counter 2'])/2
})

week_before_mt=pd.DataFrame({
    'hour':feb_mt_2023_wb['hour'],
    'counter 1': (feb_mt_2023_wb['counter 1'] + feb_mt_2024_wb['counter 1'])/2,
    'counter 2': (feb_mt_2023_wb['counter 2'] + feb_mt_2024_wb['counter 2'])/2
})

week_after_mt=pd.DataFrame({
    'hour':feb_mt_2023_wa['hour'],
    'counter 1': (feb_mt_2023_wa['counter 1'] + feb_mt_2024_wa['counter 1'] )/2,
    'counter 2': (feb_mt_2023_wa['counter 2'] + feb_mt_2024_wa['counter 2'] )/2
})
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1389640\2071155224.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feb_mt_2023['hour']=pd.to_datetime(feb_mt_2023['Timestamp'],utc=True).dt.hour
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1389640\2071155224.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feb_mt_2023_wb['hour']=pd.to_datetime(feb_mt_2023_wb['Timestamp'],utc=True).dt.hour
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1389640\2071155224.py:3: SettingWithCopyWarning:
# ...

# %%
week_before_mt['week_type']='School Week 1'
mid_term['week_type']='Mid-Term Break'
week_after_mt['week_type']='School Week 2'


comb_df=pd.concat([week_before_mt, mid_term])
comb_df=pd.concat([comb_df,week_after_mt])
# comb_df['hour']=pd.to_datetime(comb_df['datetime']).dt.hour
comb_df
# Out:
#      hour  counter 1  counter 2      week_type
# 0       0      134.5      394.0  School Week 1
# 1       1      134.0      285.5  School Week 1
# 2       2      107.0      242.0  School Week 1
# 3       3       78.0      233.5  School Week 1
# 4       4       38.5      157.5  School Week 1
# ..    ...        ...        ...            ...
# 115    19      551.5     2101.5  School Week 2
# 116    20      439.0     1396.5  School Week 2
# 117    21      337.0     1204.0  School Week 2
# 118    22      241.0      885.0  School Week 2
# 119    23      187.5      629.0  School Week 2
#
# [360 rows x 4 columns]

# %%
feb_mt_2023['week_type']='Mid-Term Break'
feb_mt_2024['week_type']='Mid-Term Break'

feb_mt_2023['week_type']='Mid-Term Break'

feb_mt_2024_wa['week_type']='School Week 2'
feb_mt_2023_wa['week_type']='School Week 2'

feb_mt_2024_wb['week_type']='School Week 1'
feb_mt_2023_wb['week_type']='School Week 1'

comb_df=pd.concat([feb_mt_2023,feb_mt_2024])
comb_df=pd.concat([feb_mt_2023_wb,comb_df])
comb_df=pd.concat([feb_mt_2023_wa,comb_df])
comb_df=pd.concat([feb_mt_2024_wb,comb_df])
comb_df=pd.concat([feb_mt_2024_wa,comb_df])
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1389640\3353626353.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feb_mt_2023['week_type']='Mid-Term Break'
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1389640\3353626353.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feb_mt_2024['week_type']='Mid-Term Break'
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1389640\3353626353.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
comb_df2=pd.concat([oct])

# %%
comb_df.head()
# Out:
#                    Timestamp  counter 1  counter 2        date      week_type  \
# 0  2024-02-19 00:00:00+00:00       62.0      167.0  2024-02-19  School Week 2
# 1  2024-02-19 01:00:00+00:00       40.0      100.0  2024-02-19  School Week 2
# 2  2024-02-19 02:00:00+00:00       18.0       81.0  2024-02-19  School Week 2
# 3  2024-02-19 03:00:00+00:00       16.0      107.0  2024-02-19  School Week 2
# 4  2024-02-19 04:00:00+00:00       27.0      208.0  2024-02-19  School Week 2
#
#    hour
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
comb_df['hour']=pd.to_datetime(comb_df['Timestamp'],utc=True).dt.hour

# %%
comb_df.head()
# Out:
#                    Timestamp  counter 1  counter 2        date      week_type  \
# 0  2024-02-19 00:00:00+00:00       62.0      167.0  2024-02-19  School Week 2
# 1  2024-02-19 01:00:00+00:00       40.0      100.0  2024-02-19  School Week 2
# 2  2024-02-19 02:00:00+00:00       18.0       81.0  2024-02-19  School Week 2
# 3  2024-02-19 03:00:00+00:00       16.0      107.0  2024-02-19  School Week 2
# 4  2024-02-19 04:00:00+00:00       27.0      208.0  2024-02-19  School Week 2
#
#    hour
# 0     0
# 1     1
# 2     2
# 3     3
# 4     4

# %%
comb_df[comb_df['counter 1'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Timestamp, counter 1, counter 2, date, week_type, hour]
# Index: []

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
# error bars based on 95% confidence interval

agg_df_c1 = comb_df.groupby(["week_type", "hour"])["counter 1"].agg(['mean', 'std', 'count']).reset_index()
agg_df_c2 = comb_df.groupby(["week_type", "hour"])["counter 2"].agg(['mean', 'std', 'count']).reset_index()

# %%
agg_df_c1['sem'] = agg_df_c1['std'] / agg_df_c1['count']**0.5  # Standard error
agg_df_c1['ci95'] = agg_df_c1['sem'] * stats.t.ppf(0.975, df=agg_df_c1['count'] - 1)

# %%
agg_df_c2['sem'] = agg_df_c2['std'] / agg_df_c2['count']**0.5  # Standard error
agg_df_c2['ci95'] = agg_df_c2['sem'] * stats.t.ppf(0.975, df=agg_df_c2['count'] - 1)

# %%
print(agg_df_c1[['week_type', 'hour', 'mean', 'std', 'count', 'sem', 'ci95']].head(10))
# Out:
#         week_type  hour   mean         std  count        sem       ci95
# 0  Mid-Term Break     0   90.4   30.332234     10   9.591895  21.698373
# 1  Mid-Term Break     1   76.8   27.222540     10   8.608523  19.473832
# 2  Mid-Term Break     2   63.4   25.509040     10   8.066667  18.248068
# 3  Mid-Term Break     3   34.0   20.072092     10   6.347353  14.358710
# 4  Mid-Term Break     4   26.7    7.379401     10   2.333571   5.278905
# 5  Mid-Term Break     5   57.5    7.849275     10   2.482159   5.615033
# 6  Mid-Term Break     6  197.9   11.599329     10   3.668030   8.297660
# 7  Mid-Term Break     7  654.7   44.191628     10  13.974620  31.612786
# 8  Mid-Term Break     8  853.4  110.536269     10  34.954637  79.072883
# 9  Mid-Term Break     9  708.6   47.039463     10  14.875184  33.650005

# %%
pivot_mean1 = agg_df_c1.pivot(index='hour', columns='week_type', values='mean')
pivot_ci1 = agg_df_c1.pivot(index='hour', columns='week_type', values='ci95')

pivot_mean2 = agg_df_c2.pivot(index='hour', columns='week_type', values='mean')
pivot_ci2 = agg_df_c2.pivot(index='hour', columns='week_type', values='ci95')

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
for week in pivot_mean1.columns:
    x = pivot_mean1.index
    y = pivot_mean1[week]
    ci = pivot_ci1[week]

    plt.plot(x, y, label=week)  
    plt.fill_between(x, y - ci, y + ci, alpha=0.2)  # Shaded area for ±1 std dev

# plt.title("Traffic Volume on Carrigrohane to Cork City, Western Road (95% CI) ")
plt.xlabel("Hour")
plt.ylabel("Mean Traffic Counts")
plt.legend()
plt.grid(True)
# Set the y-axis range from 0 to 3000
plt.ylim(0, 1500)
plt.tight_layout()
# plt.show()

plt.subplot(1,2,2)
for week in pivot_mean2.columns:
    x = pivot_mean2.index
    y = pivot_mean2[week]
    ci = pivot_ci2[week]

    plt.plot(x, y, label=week)  
    plt.fill_between(x, y - ci, y + ci, alpha=0.2)  # Shaded area for ±1 std dev
    
# plt.title("Traffic Volume on Cork & N40 Southlink road Cork (95% CI)")
plt.xlabel("Hour")
plt.ylabel("Mean Traffic Counts")
plt.legend()
plt.grid(True)
# Set the y-axis range from 0 to 3000
plt.ylim(0, 3500)
plt.tight_layout()
plt.show()

# %%
# error bars based on standard deviation 
agg_df_c1 = comb_df.groupby(["week_type", "hour"])["counter 1"].agg(['mean', 'std']).reset_index()
agg_df_c2 = comb_df.groupby(["week_type", "hour"])["counter 2"].agg(['mean', 'std']).reset_index()

# pivot_df = agg_df_c2.pivot(index='hour', columns='week_type', values='mean')
# stds = agg_df_c2.pivot(index='hour', columns='week_type', values='std')


# agg_df_c1 = comb_df.groupby(["week_type", "hour"])["counter 1"].agg(['mean', 'std']).reset_index()

pivot_mean1 = agg_df_c1.pivot(index='hour', columns='week_type', values='mean')
pivot_std1 = agg_df_c1.pivot(index='hour', columns='week_type', values='std')

pivot_mean2 = agg_df_c2.pivot(index='hour', columns='week_type', values='mean')
pivot_std2 = agg_df_c2.pivot(index='hour', columns='week_type', values='std')


plt.figure(figsize=(14,6))

plt.subplot(1,2,1)
for week in pivot_mean1.columns:
    x = pivot_mean1.index
    y = pivot_mean1[week]
    std = pivot_std1[week]

    plt.plot(x, y, label=week)  
    plt.fill_between(x, y - std, y + std, alpha=0.2)  # Shaded area for ±1 std dev


plt.title("Traffic Volume (Mean ± Std Dev) on Carrigrohane to Cork City, Western Road")
plt.xlabel("Hour")
plt.ylabel("Mean Traffic Volume")
plt.legend()
plt.grid(True)
plt.ylim(0, 4000)
plt.tight_layout()
# plt.show()

plt.subplot(1,2,2)
for week in pivot_mean2.columns:
    x = pivot_mean2.index
    y = pivot_mean2[week]
    std = pivot_std2[week]

    plt.plot(x, y, label=week)  
    plt.fill_between(x, y - std, y + std, alpha=0.2)  # Shaded area for ±1 std dev
    
plt.title("Traffic Volume (Mean ± Std Dev) on Cork & N40 Southlink road Cork ")
plt.xlabel("Hour")
plt.ylabel("Mean Traffic Volume")
plt.legend()
plt.grid(True)
# Set the y-axis range from 0 to 3000
plt.ylim(0, 4000)
plt.tight_layout()
plt.show()

# %%
pivot_df
# Out:
# week_type  Mid-Term Break  School Week 1  School Week 2
# hour
# 0                   406.4          270.2          199.8
# 1                   328.6          139.6          105.6
# 2                   294.0          117.2          108.0
# 3                   256.6          120.2          111.6
# 4                   229.2          208.4          194.8
# 5                   363.2          434.4          436.4
# 6                   918.2         1110.4         1132.2
# 7                  1866.6         2474.2         2656.4
# 8                  1974.8         2884.2         3028.2
# 9                  1871.0         2398.2         2374.6
# 10                 1946.4         2119.6         2072.4
# 11                 2118.0         2104.0         2191.8
# 12                 2328.8         2320.6         2226.8
# 13                 2452.2         2402.4         2412.0
# 14                 2430.4         2457.0         2457.8
# 15                 2409.4         2673.8         2658.6
# ...

# %%
plt.figure(figsize=(12,6))
plt.errorbar(pivot_df.index, pivot_df["School Week 1"], yerr=stds["School Week 1"], fmt='-o', label="School Week 1")
plt.errorbar(pivot_df.index, pivot_df["Mid-Term Break"], yerr=stds["Mid-Term Break"], fmt='-s', label="Mid-Term Week")
plt.errorbar(pivot_df.index, pivot_df["School Week 2"], yerr=stds["School Week 2"], fmt='-o', label="School Week 2")

plt.title("Hourly Traffic Volume Comparison (Counter 1): School vs Mid-Term Week")
plt.xlabel("Hour of Day")
plt.ylabel("Mean Traffic Volume")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
traffic=pd.read_csv('../mydata/traffic/combined_traffic_ct_1_2.csv')
traffic.head()
# Out:
#    Unnamed: 0                 date  counter 1  counter 2
# 0           0  2023-07-01 00:00:00      128.0      546.0
# 1           1  2023-07-01 01:00:00      109.0      332.0
# 2           2  2023-07-01 02:00:00      101.0      311.0
# 3           3  2023-07-01 03:00:00       52.0      270.0
# 4           4  2023-07-01 04:00:00       44.0      227.0

# %%
traffic.head()
# Out:
#    Unnamed: 0                 date  counter 1  counter 2  day_of_week
# 0           0  2023-07-01 00:00:00      128.0      546.0            5
# 1           1  2023-07-01 01:00:00      109.0      332.0            5
# 2           2  2023-07-01 02:00:00      101.0      311.0            5
# 3           3  2023-07-01 03:00:00       52.0      270.0            5
# 4           4  2023-07-01 04:00:00       44.0      227.0            5

# %%
# traffic.drop(columns=traffic.columns[0], axis=1, inplace=True)
traffic['day_of_week']=pd.to_datetime(traffic['date']).dt.day_of_week
# traffic['date']=pd.to_datetime(traffic['date']).dt.date

traf_wdays_only=traffic[~((traffic['day_of_week']==5) | (traffic['day_of_week']==6))]
traffic
# Out:
#       Unnamed: 0                 date  counter 1  counter 2  day_of_week
# 0              0  2023-07-01 00:00:00      128.0      546.0            5
# 1              1  2023-07-01 01:00:00      109.0      332.0            5
# 2              2  2023-07-01 02:00:00      101.0      311.0            5
# 3              3  2023-07-01 03:00:00       52.0      270.0            5
# 4              4  2023-07-01 04:00:00       44.0      227.0            5
# ...          ...                  ...        ...        ...          ...
# 9523        9523  2024-07-31 19:00:00      518.0     1990.0            2
# 9524        9524  2024-07-31 20:00:00      445.0     1569.0            2
# 9525        9525  2024-07-31 21:00:00      357.0     1258.0            2
# 9526        9526  2024-07-31 22:00:00      211.0      881.0            2
# 9527        9527  2024-07-31 23:00:00      114.0      544.0            2
#
# [9528 rows x 5 columns]

# %%
traf_wdays_only[traf_wdays_only['counter 2'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, date, counter 1, counter 2, day_of_week]
# Index: []

# %%
traf_wdays_only.dropna(subset=['date'], inplace=True)
traf_wdays_only[traf_wdays_only['counter 2'].isnull()]
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1389640\1218672380.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   traf_wdays_only.dropna(subset=['date'], inplace=True)
# Empty DataFrame
# Columns: [Unnamed: 0, date, counter 1, counter 2, day_of_week]
# Index: []

# %%
traf_wdays_only.head()
traf_wdays_only.rename(columns={'date':'datetime'}, inplace=True)
traf_wdays_only['date']=pd.to_datetime(traf_wdays_only['datetime']).dt.date
traf_wdays_only.head()
# ?
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1389640\2762633172.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   traf_wdays_only.rename(columns={'date':'datetime'}, inplace=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1389640\2762633172.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   traf_wdays_only['date']=pd.to_datetime(traf_wdays_only['datetime']).dt.date
#     Unnamed: 0             datetime  counter 1  counter 2  day_of_week  \
# 48          48  2023-07-03 00:00:00       67.0      310.0            0
# ...

# %%
## removing bank holidays
traf_wdays_only=traf_wdays_only[~((traf_wdays_only['date']==pd.to_datetime('2024-02-05').date()) |
(traf_wdays_only['date']==pd.to_datetime('2024-03-17').date()) |
(traf_wdays_only['date']==pd.to_datetime('2023-04-10').date()) |
(traf_wdays_only['date']==pd.to_datetime('2024-04-01').date()) |
(traf_wdays_only['date']==pd.to_datetime('2023-05-01').date()) |
(traf_wdays_only['date']==pd.to_datetime('2024-05-06').date()) |
(traf_wdays_only['date']==pd.to_datetime('2023-02-06').date()) |
(traf_wdays_only['date']==pd.to_datetime('2023-03-17').date()) |
(traf_wdays_only['date']==pd.to_datetime('2023-06-05').date()) |
(traf_wdays_only['date']==pd.to_datetime('2024-06-03').date()) )]

# %%
from datetime import datetime
summer_break_start_23= datetime.strptime("2023-07-01", "%Y-%m-%d").date()
summer_break_end_23 = datetime.strptime("2023-08-27", "%Y-%m-%d").date()
summer_break_start_24= datetime.strptime("2024-07-01", "%Y-%m-%d").date()
summer_break_end_24 = datetime.strptime("2024-08-30", "%Y-%m-%d").date()

oct_break_start_23= datetime.strptime("2023-10-30", "%Y-%m-%d").date()
oct_break_end_23 = datetime.strptime("2023-11-03", "%Y-%m-%d").date()
oct_break_start_24= datetime.strptime("2024-10-28", "%Y-%m-%d").date()
oct_break_end_24 = datetime.strptime("2024-11-01", "%Y-%m-%d").date()

christmas_break_start_23= datetime.strptime("2023-12-23", "%Y-%m-%d").date()
christmas_break_end_23 = datetime.strptime("2024-01-07", "%Y-%m-%d").date()
christmas_break_start_24= datetime.strptime("2024-12-21", "%Y-%m-%d").date()
christmas_break_end_24 = datetime.strptime("2025-01-05", "%Y-%m-%d").date()

feb_break_start_23= datetime.strptime("2023-02-13", "%Y-%m-%d").date()
feb_break_end_23 = datetime.strptime("2023-02-17", "%Y-%m-%d").date()
feb_break_start_24= datetime.strptime("2024-02-12", "%Y-%m-%d").date()
feb_break_end_24 = datetime.strptime("2024-02-16", "%Y-%m-%d").date()

easter_break_start_23= datetime.strptime("2023-04-01", "%Y-%m-%d").date()
easter_break_end_23 = datetime.strptime("2023-04-16", "%Y-%m-%d").date()
easter_break_start_24= datetime.strptime("2024-03-23", "%Y-%m-%d").date()
easter_break_end_24 = datetime.strptime("2024-04-07", "%Y-%m-%d").date()

summer_break=traf_wdays_only[(((traf_wdays_only['date']>=summer_break_start_23) & (traf_wdays_only['date']<=summer_break_end_23)) | 
                             ((traf_wdays_only['date']>=summer_break_start_24) & (traf_wdays_only['date']<=summer_break_end_24)))]

oct_break=traf_wdays_only[(((traf_wdays_only['date']>=oct_break_start_23) & (traf_wdays_only['date']<=oct_break_end_23)) | 
                          ((traf_wdays_only['date']>=oct_break_start_24) & (traf_wdays_only['date']<=oct_break_end_24)))]

christmas_break=traf_wdays_only[(((traf_wdays_only['date']>=christmas_break_start_23) & (traf_wdays_only['date']<=christmas_break_end_23)) |
                                ((traf_wdays_only['date']>=christmas_break_start_24) & (traf_wdays_only['date']<=christmas_break_end_24)))]

feb_break=traf_wdays_only[(((traf_wdays_only['date']>=feb_break_start_23) & (traf_wdays_only['date']<=feb_break_end_23)) | 
                          ((traf_wdays_only['date']>=feb_break_start_24) & (traf_wdays_only['date']<=feb_break_end_24)))]

easter_break=traf_wdays_only[(((traf_wdays_only['date']>=easter_break_start_23) & (traf_wdays_only['date']<=easter_break_end_23)) |
                             ((traf_wdays_only['date']>=easter_break_start_24) & (traf_wdays_only['date']<=easter_break_end_24)))]

summer_break['Week_Type']='Summer Break'
oct_break['Week_Type']='October Mid Term Break'
christmas_break['Week_Type']='Christmas Break'
feb_break['Week_Type']='February Mid Term Break'
easter_break['Week_Type']='Easter Break'

term_breaks=pd.concat([summer_break,oct_break,christmas_break,feb_break,easter_break])

term_breaks
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1389640\3375244708.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summer_break['Week_Type']='Summer Break'
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1389640\3375244708.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oct_break['Week_Type']='October Mid Term Break'
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1389640\3375244708.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
term_breaks.reset_index(inplace=True)
# print(term_breaks['day'].unique())
term_breaks
# Out:
#       index  Unnamed: 0             datetime  counter 1  counter 2  \
# 0        48          48  2023-07-03 00:00:00       67.0      310.0
# 1        49          49  2023-07-03 01:00:00       42.0      142.0
# 2        50          50  2023-07-03 02:00:00       47.0      124.0
# 3        51          51  2023-07-03 03:00:00       36.0      131.0
# 4        52          52  2023-07-03 04:00:00       30.0      189.0
# ...     ...         ...                  ...        ...        ...
# 2203   6715        6715  2024-04-05 19:00:00      535.0     2056.0
# 2204   6716        6716  2024-04-05 20:00:00      374.0     1427.0
# 2205   6717        6717  2024-04-05 21:00:00      287.0     1044.0
# 2206   6718        6718  2024-04-05 22:00:00      241.0      885.0
# 2207   6719        6719  2024-04-05 23:00:00      195.0      581.0
#
#       day_of_week        date     Week_Type
# 0               0  2023-07-03  Summer Break
# 1               0  2023-07-03  Summer Break
# ...

# %%
school_days=traf_wdays_only[
    ~(((traf_wdays_only['date']>=summer_break_start_23) & (traf_wdays_only['date']<=summer_break_end_23)) | 
    ((traf_wdays_only['date']>=summer_break_start_24) & (traf_wdays_only['date']<=summer_break_end_24)) |
    ((traf_wdays_only['date']>=oct_break_start_23) & (traf_wdays_only['date']<=oct_break_end_23)) | 
    ((traf_wdays_only['date']>=oct_break_start_24) & (traf_wdays_only['date']<=oct_break_end_24)) |
    ((traf_wdays_only['date']>=christmas_break_start_23) & (traf_wdays_only['date']<=christmas_break_end_23)) |
    ((traf_wdays_only['date']>=christmas_break_start_24) & (traf_wdays_only['date']<=christmas_break_end_24)) |
    ((traf_wdays_only['date']>=feb_break_start_23) & (traf_wdays_only['date']<=feb_break_end_23)) | 
    ((traf_wdays_only['date']>=feb_break_start_24) & (traf_wdays_only['date']<=feb_break_end_24)) |
    ((traf_wdays_only['date']>=easter_break_start_23) & (traf_wdays_only['date']<=easter_break_end_23)) |
    ((traf_wdays_only['date']>=easter_break_start_24) & (traf_wdays_only['date']<=easter_break_end_24)))
]

# %%
school_days.reset_index(inplace=True)

# %%
school_days
# Out:
#       index  Unnamed: 0             datetime  counter 1  counter 2  \
# 0      1392        1392  2023-08-28 00:00:00       75.0      218.0
# 1      1393        1393  2023-08-28 01:00:00       44.0      142.0
# 2      1394        1394  2023-08-28 02:00:00       38.0      130.0
# 3      1395        1395  2023-08-28 03:00:00       20.0      127.0
# 4      1396        1396  2023-08-28 04:00:00       23.0      182.0
# ...     ...         ...                  ...        ...        ...
# 4483   8731        8731  2024-06-28 19:00:00      541.0     1965.0
# 4484   8732        8732  2024-06-28 20:00:00      447.0     1433.0
# 4485   8733        8733  2024-06-28 21:00:00      358.0     1031.0
# 4486   8734        8734  2024-06-28 22:00:00      317.0     1234.0
# 4487   8735        8735  2024-06-28 23:00:00      256.0      869.0
#
#       day_of_week        date
# 0               0  2023-08-28
# 1               0  2023-08-28
# 2               0  2023-08-28
# 3               0  2023-08-28
# ...

# %%
school_days.drop(columns=['index'], axis=1, inplace=True)
term_breaks.drop(columns=['index'], axis=1, inplace=True)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1389640\3531627988.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   school_days.drop(columns=['index'], axis=1, inplace=True)

# %%
school_days['Week_Type']='School Working Days'
comb_df=pd.concat([school_days, term_breaks])
comb_df
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1389640\3487949108.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   school_days['Week_Type']='School Working Days'
#       Unnamed: 0             datetime  counter 1  counter 2  day_of_week  \
# 0           1392  2023-08-28 00:00:00       75.0      218.0            0
# 1           1393  2023-08-28 01:00:00       44.0      142.0            0
# 2           1394  2023-08-28 02:00:00       38.0      130.0            0
# 3           1395  2023-08-28 03:00:00       20.0      127.0            0
# 4           1396  2023-08-28 04:00:00       23.0      182.0            0
# ...          ...                  ...        ...        ...          ...
# ...

# %%
comb_df['datetime']=pd.to_datetime(comb_df['datetime'])
# how to sort a dataframe based on a column in python?
comb_df_sorted = comb_df.sort_values(by='datetime')
comb_df_sorted
# Out:
#       Unnamed: 0            datetime  counter 1  counter 2  day_of_week  \
# 0             48 2023-07-03 00:00:00       67.0      310.0            0
# 1             49 2023-07-03 01:00:00       42.0      142.0            0
# 2             50 2023-07-03 02:00:00       47.0      124.0            0
# 3             51 2023-07-03 03:00:00       36.0      131.0            0
# 4             52 2023-07-03 04:00:00       30.0      189.0            0
# ...          ...                 ...        ...        ...          ...
# 1507        9523 2024-07-31 19:00:00      518.0     1990.0            2
# 1508        9524 2024-07-31 20:00:00      445.0     1569.0            2
# 1509        9525 2024-07-31 21:00:00      357.0     1258.0            2
# 1510        9526 2024-07-31 22:00:00      211.0      881.0            2
# 1511        9527 2024-07-31 23:00:00      114.0      544.0            2
#
#             date     Week_Type
# 0     2023-07-03  Summer Break
# 1     2023-07-03  Summer Break
# ...

# %%
comb_df_sorted.reset_index(inplace=True)
comb_df_sorted
# Out:
#       index  Unnamed: 0            datetime  counter 1  counter 2  \
# 0         0          48 2023-07-03 00:00:00       67.0      310.0
# 1         1          49 2023-07-03 01:00:00       42.0      142.0
# 2         2          50 2023-07-03 02:00:00       47.0      124.0
# 3         3          51 2023-07-03 03:00:00       36.0      131.0
# 4         4          52 2023-07-03 04:00:00       30.0      189.0
# ...     ...         ...                 ...        ...        ...
# 6691   1507        9523 2024-07-31 19:00:00      518.0     1990.0
# 6692   1508        9524 2024-07-31 20:00:00      445.0     1569.0
# 6693   1509        9525 2024-07-31 21:00:00      357.0     1258.0
# 6694   1510        9526 2024-07-31 22:00:00      211.0      881.0
# 6695   1511        9527 2024-07-31 23:00:00      114.0      544.0
#
#       day_of_week        date     Week_Type
# 0               0  2023-07-03  Summer Break
# 1               0  2023-07-03  Summer Break
# ...

# %%
comb_df_sorted.drop(columns=['index','Unnamed: 0'], inplace=True)

# %%
comb_df_sorted['hour']=pd.to_datetime(comb_df_sorted['datetime']).dt.hour
agg_df_c1 = comb_df_sorted.groupby(["Week_Type", "hour"])["counter 1"].agg(['mean', 'std', 'count']).reset_index()
agg_df_c2 = comb_df_sorted.groupby(["Week_Type", "hour"])["counter 2"].agg(['mean', 'std', 'count']).reset_index()


agg_df_c1['sem'] = agg_df_c1['std'] / agg_df_c1['count']**0.5  # Standard error
agg_df_c1['ci95'] = agg_df_c1['sem'] * stats.t.ppf(0.975, df=agg_df_c1['count'] - 1)

agg_df_c2['sem'] = agg_df_c2['std'] / agg_df_c2['count']**0.5  # Standard error
agg_df_c2['ci95'] = agg_df_c2['sem'] * stats.t.ppf(0.975, df=agg_df_c2['count'] - 1)


pivot_mean1 = agg_df_c1.pivot(index='hour', columns='Week_Type', values='mean')
pivot_ci1 = agg_df_c1.pivot(index='hour', columns='Week_Type', values='ci95')

pivot_mean2 = agg_df_c2.pivot(index='hour', columns='Week_Type', values='mean')
pivot_ci2 = agg_df_c2.pivot(index='hour', columns='Week_Type', values='ci95')

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
for week in pivot_mean1.columns:
    x = pivot_mean1.index
    y = pivot_mean1[week]
    ci = pivot_ci1[week]

    plt.plot(x, y, label=week)  
    plt.fill_between(x, y - ci, y + ci, alpha=0.2) 

plt.title("Traffic Volume with 95% Confidence Interval")
plt.xlabel("Hour")
plt.ylabel("Mean Traffic Volume")
plt.legend()
plt.grid(True)
plt.ylim(0, 3500)
plt.tight_layout()
# plt.show()

plt.subplot(1,2,2)
for week in pivot_mean2.columns:
    x = pivot_mean2.index
    y = pivot_mean2[week]
    ci = pivot_ci2[week]

    plt.plot(x, y, label=week)  
    plt.fill_between(x, y - ci, y + ci, alpha=0.2)  # Shaded area for ±1 std dev
    
plt.title("Traffic Volume on Cork & N40 Southlink road Cork (95% CI)")
plt.xlabel("Hour")
plt.ylabel("Mean Traffic Volume")
plt.legend()
plt.grid(True)
# Set the y-axis range from 0 to 3000
plt.ylim(0, 3500)
plt.tight_layout()
plt.show()

# %%
################################### summer break ######################################
comb_df=pd.concat([summer_break, school_days])

comb_df['datetime']=pd.to_datetime(comb_df['datetime'])
# how to sort a dataframe based on a column in python?
comb_df_sorted = comb_df.sort_values(by='datetime')
comb_df_sorted


comb_df_sorted.reset_index(inplace=True)
comb_df_sorted

comb_df_sorted['hour']=pd.to_datetime(comb_df_sorted['datetime']).dt.hour
agg_df_c1 = comb_df_sorted.groupby(["Week_Type", "hour"])["counter 1"].agg(['mean', 'std', 'count']).reset_index()
agg_df_c2 = comb_df_sorted.groupby(["Week_Type", "hour"])["counter 2"].agg(['mean', 'std', 'count']).reset_index()


agg_df_c1['sem'] = agg_df_c1['std'] / agg_df_c1['count']**0.5  # Standard error
agg_df_c1['ci95'] = agg_df_c1['sem'] * stats.t.ppf(0.975, df=agg_df_c1['count'] - 1)


agg_df_c2['sem'] = agg_df_c2['std'] / agg_df_c2['count']**0.5  # Standard error
agg_df_c2['ci95'] = agg_df_c2['sem'] * stats.t.ppf(0.975, df=agg_df_c2['count'] - 1)



pivot_mean = agg_df_c1.pivot(index='hour', columns='Week_Type', values='mean')
pivot_ci = agg_df_c1.pivot(index='hour', columns='Week_Type', values='ci95')

pivot_mean2 = agg_df_c2.pivot(index='hour', columns='Week_Type', values='mean')
pivot_ci2 = agg_df_c2.pivot(index='hour', columns='Week_Type', values='ci95')


plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
for week in pivot_mean.columns:
    plt.errorbar(pivot_mean.index,
                 pivot_mean[week],
                 yerr=pivot_ci[week],
                 fmt='-o',
                 label=week)
    
# plt.title("Traffic Volume on Carrigrohane to Cork City, Western Road (95% CI)")
plt.xlabel("Hour")
plt.ylabel("Mean Traffic Counts")
plt.legend()
plt.grid(True)
plt.ylim(0, 1500)
plt.tight_layout()

    
plt.subplot(1,2,2)
for week in pivot_mean2.columns:
    plt.errorbar(pivot_mean2.index,
                 pivot_mean2[week],
                 yerr=pivot_ci2[week],
                 fmt='-o',
                 label=week)

# plt.title("Traffic Volume on Cork & N40 Southlink road Cork (95% CI)")
plt.xlabel("Hour")
plt.ylabel("Mean Traffic Counts")
plt.legend()
plt.grid(True)
plt.ylim(0, 3500)
plt.tight_layout()
plt.show()

# %%
################################### christmas break ######################################
comb_df=pd.concat([christmas_break, school_days])


comb_df['datetime']=pd.to_datetime(comb_df['datetime'])
# how to sort a dataframe based on a column in python?
comb_df_sorted = comb_df.sort_values(by='datetime')
comb_df_sorted


comb_df_sorted.reset_index(inplace=True)
comb_df_sorted

comb_df_sorted['hour']=pd.to_datetime(comb_df_sorted['datetime']).dt.hour
agg_df_c1 = comb_df_sorted.groupby(["Week_Type", "hour"])["counter 1"].agg(['mean', 'std', 'count']).reset_index()
agg_df_c2 = comb_df_sorted.groupby(["Week_Type", "hour"])["counter 2"].agg(['mean', 'std', 'count']).reset_index()


agg_df_c1['sem'] = agg_df_c1['std'] / agg_df_c1['count']**0.5  # Standard error
agg_df_c1['ci95'] = agg_df_c1['sem'] * stats.t.ppf(0.975, df=agg_df_c1['count'] - 1)


agg_df_c2['sem'] = agg_df_c2['std'] / agg_df_c2['count']**0.5  # Standard error
agg_df_c2['ci95'] = agg_df_c2['sem'] * stats.t.ppf(0.975, df=agg_df_c2['count'] - 1)



pivot_mean = agg_df_c1.pivot(index='hour', columns='Week_Type', values='mean')
pivot_ci = agg_df_c1.pivot(index='hour', columns='Week_Type', values='ci95')

pivot_mean2 = agg_df_c2.pivot(index='hour', columns='Week_Type', values='mean')
pivot_ci2 = agg_df_c2.pivot(index='hour', columns='Week_Type', values='ci95')


plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
for week in pivot_mean.columns:
    plt.errorbar(pivot_mean.index,
                 pivot_mean[week],
                 yerr=pivot_ci[week],
                 fmt='-o',
                 label=week)
    
plt.title("Traffic Volume on Carrigrohane to Cork City, Western Road (95% CI)")
plt.xlabel("Hour")
plt.ylabel("Mean Traffic Volume")
plt.legend()
plt.grid(True)
plt.ylim(0, 3500)
plt.tight_layout()

    
plt.subplot(1,2,2)
for week in pivot_mean2.columns:
    plt.errorbar(pivot_mean2.index,
                 pivot_mean2[week],
                 yerr=pivot_ci2[week],
                 fmt='-o',
                 label=week)

plt.title("Traffic Volume on Cork & N40 Southlink road Cork (95% CI)")
plt.xlabel("Hour")
plt.ylabel("Mean Traffic Volume")
plt.legend()
plt.grid(True)
plt.ylim(0, 3500)
plt.tight_layout()
plt.show()

# %%
################################### october break ######################################
comb_df=pd.concat([oct_break, school_days])

comb_df['datetime']=pd.to_datetime(comb_df['datetime'])
# how to sort a dataframe based on a column in python?
comb_df_sorted = comb_df.sort_values(by='datetime')
comb_df_sorted


comb_df_sorted.reset_index(inplace=True)
comb_df_sorted

comb_df_sorted['hour']=pd.to_datetime(comb_df_sorted['datetime']).dt.hour
agg_df_c1 = comb_df_sorted.groupby(["Week_Type", "hour"])["counter 1"].agg(['mean', 'std', 'count']).reset_index()
agg_df_c2 = comb_df_sorted.groupby(["Week_Type", "hour"])["counter 2"].agg(['mean', 'std', 'count']).reset_index()


agg_df_c1['sem'] = agg_df_c1['std'] / agg_df_c1['count']**0.5  # Standard error
agg_df_c1['ci95'] = agg_df_c1['sem'] * stats.t.ppf(0.975, df=agg_df_c1['count'] - 1)


agg_df_c2['sem'] = agg_df_c2['std'] / agg_df_c2['count']**0.5  # Standard error
agg_df_c2['ci95'] = agg_df_c2['sem'] * stats.t.ppf(0.975, df=agg_df_c2['count'] - 1)



pivot_mean = agg_df_c1.pivot(index='hour', columns='Week_Type', values='mean')
pivot_ci = agg_df_c1.pivot(index='hour', columns='Week_Type', values='ci95')

pivot_mean2 = agg_df_c2.pivot(index='hour', columns='Week_Type', values='mean')
pivot_ci2 = agg_df_c2.pivot(index='hour', columns='Week_Type', values='ci95')


plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
for week in pivot_mean.columns:
    plt.errorbar(pivot_mean.index,
                 pivot_mean[week],
                 yerr=pivot_ci[week],
                 fmt='-o',
                 label=week)
    
plt.title("Traffic Volume on Carrigrohane to Cork City, Western Road (95% CI)")
plt.xlabel("Hour")
plt.ylabel("Mean Traffic Volume")
plt.legend()
plt.grid(True)
plt.ylim(0, 3500)
plt.tight_layout()

    
plt.subplot(1,2,2)
for week in pivot_mean2.columns:
    plt.errorbar(pivot_mean2.index,
                 pivot_mean2[week],
                 yerr=pivot_ci2[week],
                 fmt='-o',
                 label=week)

plt.title("Traffic Volume on Cork & N40 Southlink road Cork (95% CI)")
plt.xlabel("Hour")
plt.ylabel("Mean Traffic Volume")
plt.legend()
plt.grid(True)
plt.ylim(0, 3500)
plt.tight_layout()
plt.show()

# %%
################################### feb break ######################################
comb_df=pd.concat([feb_break, school_days])

comb_df['datetime']=pd.to_datetime(comb_df['datetime'])
# how to sort a dataframe based on a column in python?
comb_df_sorted = comb_df.sort_values(by='datetime')
comb_df_sorted


comb_df_sorted.reset_index(inplace=True)
comb_df_sorted

comb_df_sorted['hour']=pd.to_datetime(comb_df_sorted['datetime']).dt.hour
agg_df_c1 = comb_df_sorted.groupby(["Week_Type", "hour"])["counter 1"].agg(['mean', 'std', 'count']).reset_index()
agg_df_c2 = comb_df_sorted.groupby(["Week_Type", "hour"])["counter 2"].agg(['mean', 'std', 'count']).reset_index()


agg_df_c1['sem'] = agg_df_c1['std'] / agg_df_c1['count']**0.5  # Standard error
agg_df_c1['ci95'] = agg_df_c1['sem'] * stats.t.ppf(0.975, df=agg_df_c1['count'] - 1)


agg_df_c2['sem'] = agg_df_c2['std'] / agg_df_c2['count']**0.5  # Standard error
agg_df_c2['ci95'] = agg_df_c2['sem'] * stats.t.ppf(0.975, df=agg_df_c2['count'] - 1)



pivot_mean = agg_df_c1.pivot(index='hour', columns='Week_Type', values='mean')
pivot_ci = agg_df_c1.pivot(index='hour', columns='Week_Type', values='ci95')

pivot_mean2 = agg_df_c2.pivot(index='hour', columns='Week_Type', values='mean')
pivot_ci2 = agg_df_c2.pivot(index='hour', columns='Week_Type', values='ci95')


plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
for week in pivot_mean.columns:
    plt.errorbar(pivot_mean.index,
                 pivot_mean[week],
                 yerr=pivot_ci[week],
                 fmt='-o',
                 label=week)
    
plt.title("Traffic Volume on Carrigrohane to Cork City, Western Road (95% CI)")
plt.xlabel("Hour")
plt.ylabel("Mean Traffic Volume")
plt.legend()
plt.grid(True)
plt.ylim(0, 3500)
plt.tight_layout()

    
plt.subplot(1,2,2)
for week in pivot_mean2.columns:
    plt.errorbar(pivot_mean2.index,
                 pivot_mean2[week],
                 yerr=pivot_ci2[week],
                 fmt='-o',
                 label=week)

plt.title("Traffic Volume on Cork & N40 Southlink road Cork (95% CI)")
plt.xlabel("Hour")
plt.ylabel("Mean Traffic Volume")
plt.legend()
plt.grid(True)
plt.ylim(0, 3500)
plt.tight_layout()
plt.show()

# %%
################################### easter break ######################################
comb_df=pd.concat([easter_break, school_days])

comb_df['datetime']=pd.to_datetime(comb_df['datetime'])
# how to sort a dataframe based on a column in python?
comb_df_sorted = comb_df.sort_values(by='datetime')
comb_df_sorted


comb_df_sorted.reset_index(inplace=True)
comb_df_sorted

comb_df_sorted['hour']=pd.to_datetime(comb_df_sorted['datetime']).dt.hour
agg_df_c1 = comb_df_sorted.groupby(["Week_Type", "hour"])["counter 1"].agg(['mean', 'std', 'count']).reset_index()
agg_df_c2 = comb_df_sorted.groupby(["Week_Type", "hour"])["counter 2"].agg(['mean', 'std', 'count']).reset_index()


agg_df_c1['sem'] = agg_df_c1['std'] / agg_df_c1['count']**0.5  # Standard error
agg_df_c1['ci95'] = agg_df_c1['sem'] * stats.t.ppf(0.975, df=agg_df_c1['count'] - 1)


agg_df_c2['sem'] = agg_df_c2['std'] / agg_df_c2['count']**0.5  # Standard error
agg_df_c2['ci95'] = agg_df_c2['sem'] * stats.t.ppf(0.975, df=agg_df_c2['count'] - 1)



pivot_mean = agg_df_c1.pivot(index='hour', columns='Week_Type', values='mean')
pivot_ci = agg_df_c1.pivot(index='hour', columns='Week_Type', values='ci95')

pivot_mean2 = agg_df_c2.pivot(index='hour', columns='Week_Type', values='mean')
pivot_ci2 = agg_df_c2.pivot(index='hour', columns='Week_Type', values='ci95')


plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
for week in pivot_mean.columns:
    plt.errorbar(pivot_mean.index,
                 pivot_mean[week],
                 yerr=pivot_ci[week],
                 fmt='-o',
                 label=week)
    
plt.title("Traffic Volume on Carrigrohane to Cork City, Western Road (95% CI)")
plt.xlabel("Hour")
plt.ylabel("Mean Traffic Volume")
plt.legend()
plt.grid(True)
plt.ylim(0, 3500)
plt.tight_layout()

    
plt.subplot(1,2,2)
for week in pivot_mean2.columns:
    plt.errorbar(pivot_mean2.index,
                 pivot_mean2[week],
                 yerr=pivot_ci2[week],
                 fmt='-o',
                 label=week)

plt.title("Traffic Volume on Cork & N40 Southlink road Cork (95% CI)")
plt.xlabel("Hour")
plt.ylabel("Mean Traffic Volume")
plt.legend()
plt.grid(True)
plt.ylim(0, 3500)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### PROPORTION OF CARS AND HEAVY VEHICLES

# %%
jun24_df = pd.read_csv("../mydata/traffic/counter 2/car-data/jun-24.csv")
jun24_df=jun24_df.drop(['Count','Workday','7 Day'], axis=1)
jun24_df = jun24_df.rename(columns={jun24_df.columns[0]: 'hour'})  # rename first column to 'hour'
jun24_df_long = pd.melt(jun24_df, id_vars='hour', var_name='date', value_name='value')
jun24_df_long['datetime'] = pd.to_datetime(jun24_df_long['date'].astype(str) + ' ' + jun24_df_long['hour'].astype(str))
jun24_df_long = jun24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
jun24_df_long.head()
# Out:
#              datetime  value
# 0 2024-06-01 00:00:00    507
# 1 2024-06-01 01:00:00    305
# 2 2024-06-01 02:00:00    237
# 3 2024-06-01 03:00:00    198
# 4 2024-06-01 04:00:00    188

# %%
jun23_df = pd.read_csv("../mydata/traffic/counter 2/car-data/jun-23.csv")
jun23_df=jun23_df.drop(['Count','Workday','7 Day'], axis=1)
jun23_df = jun23_df.rename(columns={jun23_df.columns[0]: 'hour'})  # rename first column to 'hour'
jun23_df_long = pd.melt(jun23_df, id_vars='hour', var_name='date', value_name='value')
jun23_df_long['datetime'] = pd.to_datetime(jun23_df_long['date'].astype(str) + ' ' + jun23_df_long['hour'].astype(str))
jun23_df_long = jun23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
jun23_df_long.head()
# Out:
#              datetime  value
# 0 2023-06-01 00:00:00    244
# 1 2023-06-01 01:00:00    129
# 2 2023-06-01 02:00:00     87
# 3 2023-06-01 03:00:00     84
# 4 2023-06-01 04:00:00    154

# %%
may24_df = pd.read_csv("../mydata/traffic/counter 2/car-data/may-24.csv")
may24_df=may24_df.drop(['Count','Workday','7 Day'], axis=1)
may24_df = may24_df.rename(columns={may24_df.columns[0]: 'hour'})  # rename first column to 'hour'
may24_df_long = pd.melt(may24_df, id_vars='hour', var_name='date', value_name='value')
may24_df_long['datetime'] = pd.to_datetime(may24_df_long['date'].astype(str) + ' ' + may24_df_long['hour'].astype(str))
may24_df_long = may24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
may24_df_long.head()
# Out:
#              datetime  value
# 0 2024-05-01 00:00:00    326
# 1 2024-05-01 01:00:00    216
# 2 2024-05-01 02:00:00    180
# 3 2024-05-01 03:00:00    159
# 4 2024-05-01 04:00:00    176

# %%
may23_df = pd.read_csv("../mydata/traffic/counter 2/car-data/may-23.csv")
may23_df=may23_df.drop(['Count','Workday','7 Day'], axis=1)
may23_df = may23_df.rename(columns={may23_df.columns[0]: 'hour'})  # rename first column to 'hour'
may23_df_long = pd.melt(may23_df, id_vars='hour', var_name='date', value_name='value')
may23_df_long['datetime'] = pd.to_datetime(may23_df_long['date'].astype(str) + ' ' + may23_df_long['hour'].astype(str))
may23_df_long = may23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
may23_df_long.head()
# Out:
#              datetime  value
# 0 2023-05-01 00:00:00    453
# 1 2023-05-01 01:00:00    324
# 2 2023-05-01 02:00:00    264
# 3 2023-05-01 03:00:00    217
# 4 2023-05-01 04:00:00    134

# %%
apr24_df = pd.read_csv("../mydata/traffic/counter 2/car-data/apr-24.csv")
apr24_df=apr24_df.drop(['Count','Workday','7 Day'], axis=1)
apr24_df = apr24_df.rename(columns={apr24_df.columns[0]: 'hour'})  # rename first column to 'hour'
apr24_df_long = pd.melt(apr24_df, id_vars='hour', var_name='date', value_name='value')
apr24_df_long['datetime'] = pd.to_datetime(apr24_df_long['date'].astype(str) + ' ' + apr24_df_long['hour'].astype(str))
apr24_df_long = apr24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
apr24_df_long.head()
# Out:
#              datetime  value
# 0 2024-04-01 00:00:00    345
# 1 2024-04-01 01:00:00    266
# 2 2024-04-01 02:00:00    195
# 3 2024-04-01 03:00:00    235
# 4 2024-04-01 04:00:00    144

# %%
apr23_df = pd.read_csv("../mydata/traffic/counter 2/car-data/apr-23.csv")
apr23_df=apr23_df.drop(['Count','Workday','7 Day'], axis=1)
apr23_df = apr23_df.rename(columns={apr23_df.columns[0]: 'hour'})  # rename first column to 'hour'
apr23_df_long = pd.melt(apr23_df, id_vars='hour', var_name='date', value_name='value')
apr23_df_long['datetime'] = pd.to_datetime(apr23_df_long['date'].astype(str) + ' ' + apr23_df_long['hour'].astype(str))
apr23_df_long = apr23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
apr23_df_long.head()
# Out:
#              datetime  value
# 0 2023-04-01 00:00:00    461
# 1 2023-04-01 01:00:00    276
# 2 2023-04-01 02:00:00    269
# 3 2023-04-01 03:00:00    180
# 4 2023-04-01 04:00:00    134

# %%
mar24_df = pd.read_csv("../mydata/traffic/counter 2/car-data/mar-24.csv")
mar24_df=mar24_df.drop(['Count','Workday','7 Day'], axis=1)
mar24_df =mar24_df.rename(columns={mar24_df.columns[0]: 'hour'})  # rename first column to 'hour'
mar24_df_long = pd.melt(mar24_df, id_vars='hour', var_name='date', value_name='value')
mar24_df_long['datetime'] = pd.to_datetime(mar24_df_long['date'].astype(str) + ' ' + mar24_df_long['hour'].astype(str))
mar24_df_long = mar24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
mar24_df_long.head()
# Out:
#              datetime  value
# 0 2024-03-01 00:00:00    264
# 1 2024-03-01 01:00:00    165
# 2 2024-03-01 02:00:00    119
# 3 2024-03-01 03:00:00     98
# 4 2024-03-01 04:00:00    137

# %%
mar23_df = pd.read_csv("../mydata/traffic/counter 2/car-data/mar-23.csv")
mar23_df=mar23_df.drop(['Count','Workday','7 Day'], axis=1)
mar23_df =mar23_df.rename(columns={mar23_df.columns[0]: 'hour'})  # rename first column to 'hour'
mar23_df_long = pd.melt(mar23_df, id_vars='hour', var_name='date', value_name='value')
mar23_df_long['datetime'] = pd.to_datetime(mar23_df_long['date'].astype(str) + ' ' + mar23_df_long['hour'].astype(str))
mar23_df_long = mar23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
mar23_df_long.head()
# Out:
#              datetime  value
# 0 2023-03-01 00:00:00    164
# 1 2023-03-01 01:00:00     86
# 2 2023-03-01 02:00:00     80
# 3 2023-03-01 03:00:00     63
# 4 2023-03-01 04:00:00    145

# %%
feb24_df = pd.read_csv("../mydata/traffic/counter 2/car-data/feb-24.csv")
feb24_df=feb24_df.drop(['Count','Workday','7 Day'], axis=1)
feb24_df =feb24_df.rename(columns={feb24_df.columns[0]: 'hour'})  # rename first column to 'hour'
feb24_df_long = pd.melt(feb24_df, id_vars='hour', var_name='date', value_name='value')
feb24_df_long['datetime'] = pd.to_datetime(feb24_df_long['date'].astype(str) + ' ' + feb24_df_long['hour'].astype(str))
feb24_df_long = feb24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
feb24_df_long.head()
# Out:
#              datetime  value
# 0 2024-02-01 00:00:00    170
# 1 2024-02-01 01:00:00    104
# 2 2024-02-01 02:00:00     74
# 3 2024-02-01 03:00:00    116
# 4 2024-02-01 04:00:00    135

# %%
feb23_df = pd.read_csv("../mydata/traffic/counter 2/car-data/feb-23.csv")
feb23_df=feb23_df.drop(['Count','Workday','7 Day'], axis=1)
feb23_df =feb23_df.rename(columns={feb23_df.columns[0]: 'hour'})  # rename first column to 'hour'
feb23_df_long = pd.melt(feb23_df, id_vars='hour', var_name='date', value_name='value')
feb23_df_long['datetime'] = pd.to_datetime(feb23_df_long['date'].astype(str) + ' ' + feb23_df_long['hour'].astype(str))
feb23_df_long = feb23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
feb23_df_long.head()
# Out:
#              datetime  value
# 0 2023-02-01 00:00:00    149
# 1 2023-02-01 01:00:00     79
# 2 2023-02-01 02:00:00     77
# 3 2023-02-01 03:00:00     47
# 4 2023-02-01 04:00:00    109

# %%
jan24_df = pd.read_csv("../mydata/traffic/counter 2/car-data/jan-24.csv")
jan24_df=jan24_df.drop(['Count','Workday','7 Day'], axis=1)
jan24_df =jan24_df.rename(columns={jan24_df.columns[0]: 'hour'})  # rename first column to 'hour'
jan24_df_long = pd.melt(jan24_df, id_vars='hour', var_name='date', value_name='value')
jan24_df_long['datetime'] = pd.to_datetime(jan24_df_long['date'].astype(str) + ' ' + jan24_df_long['hour'].astype(str))
jan24_df_long = jan24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
jan24_df_long.head()
# Out:
#              datetime  value
# 0 2024-01-01 00:00:00  499.0
# 1 2024-01-01 01:00:00  490.0
# 2 2024-01-01 02:00:00  388.0
# 3 2024-01-01 03:00:00  356.0
# 4 2024-01-01 04:00:00  191.0

# %%
jan23_df = pd.read_csv("../mydata/traffic/counter 2/car-data/jan-23.csv")
jan23_df=jan23_df.drop(['Count','Workday','7 Day'], axis=1)
jan23_df =jan23_df.rename(columns={jan23_df.columns[0]: 'hour'})  # rename first column to 'hour'
jan23_df_long = pd.melt(jan23_df, id_vars='hour', var_name='date', value_name='value')
jan23_df_long['datetime'] = pd.to_datetime(jan23_df_long['date'].astype(str) + ' ' + jan23_df_long['hour'].astype(str))
jan23_df_long = jan23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
jan23_df_long.head()
# Out:
#              datetime  value
# 0 2023-01-01 00:00:00    458
# 1 2023-01-01 01:00:00    478
# 2 2023-01-01 02:00:00    371
# 3 2023-01-01 03:00:00    304
# 4 2023-01-01 04:00:00    138

# %%
dec23_df = pd.read_csv("../mydata/traffic/counter 2/car-data/dec-23.csv")
dec23_df=dec23_df.drop(['Count','Workday','7 Day'], axis=1)
dec23_df =dec23_df.rename(columns={dec23_df.columns[0]: 'hour'})  # rename first column to 'hour'
dec23_df_long = pd.melt(dec23_df, id_vars='hour', var_name='date', value_name='value')
dec23_df_long['datetime'] = pd.to_datetime(dec23_df_long['date'].astype(str) + ' ' + dec23_df_long['hour'].astype(str))
dec23_df_long = dec23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
dec23_df_long.head()
# Out:
#              datetime  value
# 0 2023-12-01 00:00:00    424
# 1 2023-12-01 01:00:00    242
# 2 2023-12-01 02:00:00    175
# 3 2023-12-01 03:00:00    116
# 4 2023-12-01 04:00:00    161

# %%
dec24_df = pd.read_csv("../mydata/traffic/counter 2/car-data/dec-24.csv")
dec24_df=dec24_df.drop(['Count','Workday','7 Day'], axis=1)
dec24_df =dec24_df.rename(columns={dec24_df.columns[0]: 'hour'})  # rename first column to 'hour'
dec24_df_long = pd.melt(dec24_df, id_vars='hour', var_name='date', value_name='value')
dec24_df_long['datetime'] = pd.to_datetime(dec24_df_long['date'].astype(str) + ' ' + dec24_df_long['hour'].astype(str))
dec24_df_long = dec24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
dec24_df_long.head()
# Out:
#              datetime  value
# 0 2024-12-01 00:00:00    592
# 1 2024-12-01 01:00:00    451
# 2 2024-12-01 02:00:00    343
# 3 2024-12-01 03:00:00    307
# 4 2024-12-01 04:00:00    165

# %%
nov23_df = pd.read_csv("../mydata/traffic/counter 2/car-data/nov-23.csv")
nov23_df=nov23_df.drop(['Count','Workday','7 Day'], axis=1)
nov23_df =nov23_df.rename(columns={nov23_df.columns[0]: 'hour'})  # rename first column to 'hour'
nov23_df_long = pd.melt(nov23_df, id_vars='hour', var_name='date', value_name='value')
nov23_df_long['datetime'] = pd.to_datetime(nov23_df_long['date'].astype(str) + ' ' + nov23_df_long['hour'].astype(str))
nov23_df_long = nov23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
nov23_df_long.head()
# Out:
#              datetime  value
# 0 2023-11-01 00:00:00    405
# 1 2023-11-01 01:00:00    343
# 2 2023-11-01 02:00:00    307
# 3 2023-11-01 03:00:00    195
# 4 2023-11-01 04:00:00    159

# %%
nov24_df = pd.read_csv("../mydata/traffic/counter 2/car-data/nov-24.csv")
nov24_df=nov24_df.drop(['Count','Workday','7 Day'], axis=1)
nov24_df =nov24_df.rename(columns={nov24_df.columns[0]: 'hour'})  # rename first column to 'hour'
nov24_df_long = pd.melt(nov24_df, id_vars='hour', var_name='date', value_name='value')
nov24_df_long['datetime'] = pd.to_datetime(nov24_df_long['date'].astype(str) + ' ' + nov24_df_long['hour'].astype(str))
nov24_df_long = nov24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
nov24_df_long.head()
# Out:
#              datetime  value
# 0 2024-11-01 00:00:00    609
# 1 2024-11-01 01:00:00    479
# 2 2024-11-01 02:00:00    443
# 3 2024-11-01 03:00:00    277
# 4 2024-11-01 04:00:00    236

# %%
oct23_df = pd.read_csv("../mydata/traffic/counter 2/car-data/oct-23.csv")
oct23_df=oct23_df.drop(['Count','Workday','7 Day'], axis=1)
oct23_df =oct23_df.rename(columns={oct23_df.columns[0]: 'hour'})  # rename first column to 'hour'
oct23_df_long = pd.melt(oct23_df, id_vars='hour', var_name='date', value_name='value')
oct23_df_long['datetime'] = pd.to_datetime(oct23_df_long['date'].astype(str) + ' ' + oct23_df_long['hour'].astype(str))
oct23_df_long = oct23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
oct23_df_long.head()
# Out:
#              datetime  value
# 0 2023-10-01 00:00:00    477
# 1 2023-10-01 01:00:00    370
# 2 2023-10-01 02:00:00    320
# 3 2023-10-01 03:00:00    247
# 4 2023-10-01 04:00:00    185

# %%
oct24_df = pd.read_csv("../mydata/traffic/counter 2/car-data/oct-24.csv")
oct24_df=oct24_df.drop(['Count','Workday','7 Day'], axis=1)
oct24_df =oct24_df.rename(columns={oct24_df.columns[0]: 'hour'})  # rename first column to 'hour'
oct24_df_long = pd.melt(oct24_df, id_vars='hour', var_name='date', value_name='value')
oct24_df_long['datetime'] = pd.to_datetime(oct24_df_long['date'].astype(str) + ' ' + oct24_df_long['hour'].astype(str))
oct24_df_long = oct24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
oct24_df_long.head()
# Out:
#              datetime  value
# 0 2024-10-01 00:00:00    405
# 1 2024-10-01 01:00:00    168
# 2 2024-10-01 02:00:00    110
# 3 2024-10-01 03:00:00    154
# 4 2024-10-01 04:00:00    161

# %%
sep23_df = pd.read_csv("../mydata/traffic/counter 2/car-data/sep-23.csv")
sep23_df=sep23_df.drop(['Count','Workday','7 Day'], axis=1)
sep23_df =sep23_df.rename(columns={sep23_df.columns[0]: 'hour'})  # rename first column to 'hour'
sep23_df_long = pd.melt(sep23_df, id_vars='hour', var_name='date', value_name='value')
sep23_df_long['datetime'] = pd.to_datetime(sep23_df_long['date'].astype(str) + ' ' + sep23_df_long['hour'].astype(str))
sep23_df_long = sep23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
sep23_df_long.head()
# Out:
#              datetime  value
# 0 2023-09-01 00:00:00    278
# 1 2023-09-01 01:00:00    119
# 2 2023-09-01 02:00:00    114
# 3 2023-09-01 03:00:00     78
# 4 2023-09-01 04:00:00    194

# %%
sep24_df = pd.read_csv("../mydata/traffic/counter 2/car-data/sep-24.csv")
sep24_df=sep24_df.drop(['Count','Workday','7 Day'], axis=1)
sep24_df =sep24_df.rename(columns={sep24_df.columns[0]: 'hour'})  # rename first column to 'hour'
sep24_df_long = pd.melt(sep24_df, id_vars='hour', var_name='date', value_name='value')
sep24_df_long['datetime'] = pd.to_datetime(sep24_df_long['date'].astype(str) + ' ' + sep24_df_long['hour'].astype(str))
sep24_df_long = sep24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
sep24_df_long.head()
# Out:
#              datetime  value
# 0 2024-09-01 00:00:00    456
# 1 2024-09-01 01:00:00    339
# 2 2024-09-01 02:00:00    289
# 3 2024-09-01 03:00:00    287
# 4 2024-09-01 04:00:00    194

# %%
aug23_df = pd.read_csv("../mydata/traffic/counter 2/car-data/aug-23.csv")
aug23_df=aug23_df.drop(['Count','Workday','7 Day'], axis=1)
aug23_df =aug23_df.rename(columns={aug23_df.columns[0]: 'hour'})  # rename first column to 'hour'
aug23_df_long = pd.melt(aug23_df, id_vars='hour', var_name='date', value_name='value')
aug23_df_long['datetime'] = pd.to_datetime(aug23_df_long['date'].astype(str) + ' ' + aug23_df_long['hour'].astype(str))
aug23_df_long = aug23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
aug23_df_long.head()
# Out:
#              datetime  value
# 0 2023-08-01 00:00:00    298
# 1 2023-08-01 01:00:00    118
# 2 2023-08-01 02:00:00     85
# 3 2023-08-01 03:00:00     89
# 4 2023-08-01 04:00:00    150

# %%
aug24_df = pd.read_csv("../mydata/traffic/counter 2/car-data/aug-24.csv")
aug24_df=aug24_df.drop(['Count','Workday','7 Day'], axis=1)
aug24_df =aug24_df.rename(columns={aug24_df.columns[0]: 'hour'})  # rename first column to 'hour'
aug24_df_long = pd.melt(aug24_df, id_vars='hour', var_name='date', value_name='value')
aug24_df_long['datetime'] = pd.to_datetime(aug24_df_long['date'].astype(str) + ' ' + aug24_df_long['hour'].astype(str))
aug24_df_long = aug24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
aug24_df_long.head()
# Out:
#              datetime  value
# 0 2024-08-01 00:00:00    284
# 1 2024-08-01 01:00:00    158
# 2 2024-08-01 02:00:00    114
# 3 2024-08-01 03:00:00    152
# 4 2024-08-01 04:00:00    188

# %%
jul23_df = pd.read_csv("../mydata/traffic/counter 2/car-data/jul-23.csv")
jul23_df=jul23_df.drop(['Count','Workday','7 Day'], axis=1)
jul23_df =jul23_df.rename(columns={jul23_df.columns[0]: 'hour'})  # rename first column to 'hour'
jul23_df_long = pd.melt(jul23_df, id_vars='hour', var_name='date', value_name='value')
jul23_df_long['datetime'] = pd.to_datetime(jul23_df_long['date'].astype(str) + ' ' + jul23_df_long['hour'].astype(str))
jul23_df_long = jul23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
jul23_df_long.head()
# Out:
#              datetime  value
# 0 2023-07-01 00:00:00    499
# 1 2023-07-01 01:00:00    299
# 2 2023-07-01 02:00:00    274
# 3 2023-07-01 03:00:00    226
# 4 2023-07-01 04:00:00    192

# %%
jul24_df = pd.read_csv("../mydata/traffic/counter 2/car-data/jul-24.csv")
jul24_df=jul24_df.drop(['Count','Workday','7 Day'], axis=1)
jul24_df =jul24_df.rename(columns={jul24_df.columns[0]: 'hour'})  # rename first column to 'hour'
jul24_df_long = pd.melt(jul24_df, id_vars='hour', var_name='date', value_name='value')
jul24_df_long['datetime'] = pd.to_datetime(jul24_df_long['date'].astype(str) + ' ' + jul24_df_long['hour'].astype(str))
jul24_df_long = jul24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
jul24_df_long.head()
# Out:
#              datetime  value
# 0 2024-07-01 00:00:00    195
# 1 2024-07-01 01:00:00    124
# 2 2024-07-01 02:00:00    116
# 3 2024-07-01 03:00:00    201
# 4 2024-07-01 04:00:00    160

# %%
combined_df = pd.concat([nov24_df_long, dec24_df_long], ignore_index=True)
combined_df = pd.concat([oct24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([sep24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([aug24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([jul24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([jun24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([may24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([apr24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([mar24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([feb24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([jan24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([dec23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([nov23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([oct23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([sep23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([aug23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([jul23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([jun23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([may23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([apr23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([mar23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([feb23_df_long, combined_df], ignore_index=True)
combined_df1 = pd.concat([jan23_df_long, combined_df], ignore_index=True)
combined_df1.head()
# Out:
#              datetime  value
# 0 2023-01-01 00:00:00  458.0
# 1 2023-01-01 01:00:00  478.0
# 2 2023-01-01 02:00:00  371.0
# 3 2023-01-01 03:00:00  304.0
# 4 2023-01-01 04:00:00  138.0

# %%
combined_df1.to_csv('../mydata/traffic/counter 2/car_count_23_24_comp.csv')

# %%
car_r1=pd.read_csv('../mydata/traffic/counter 1/car_count_23_24_comp.csv')

# %%
car_r2=pd.read_csv('../mydata/traffic/counter 2/car_count_23_24_comp.csv')

# %%
car_r1.dropna(subset=['value'], inplace=True)

# %%
car_r2.dropna(subset=['value'], inplace=True)

# %% [markdown]
# Lighter Goods Vehicles

# %%
jun24_df = pd.read_csv("../mydata/traffic/counter 2/r2-lgv-data/jun-24.csv")
jun24_df=jun24_df.drop(['Count','Workday','7 Day'], axis=1)
jun24_df = jun24_df.rename(columns={jun24_df.columns[0]: 'hour'})  # rename first column to 'hour'
jun24_df_long = pd.melt(jun24_df, id_vars='hour', var_name='date', value_name='value')
jun24_df_long['datetime'] = pd.to_datetime(jun24_df_long['date'].astype(str) + ' ' + jun24_df_long['hour'].astype(str))
jun24_df_long = jun24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
jun24_df_long.head()

jun23_df = pd.read_csv("../mydata/traffic/counter 2/r2-lgv-data/jun-23.csv")
jun23_df=jun23_df.drop(['Count','Workday','7 Day'], axis=1)
jun23_df = jun23_df.rename(columns={jun23_df.columns[0]: 'hour'})  # rename first column to 'hour'
jun23_df_long = pd.melt(jun23_df, id_vars='hour', var_name='date', value_name='value')
jun23_df_long['datetime'] = pd.to_datetime(jun23_df_long['date'].astype(str) + ' ' + jun23_df_long['hour'].astype(str))
jun23_df_long = jun23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
jun23_df_long.head()



may24_df = pd.read_csv("../mydata/traffic/counter 2/r2-lgv-data/may-24.csv")
may24_df=may24_df.drop(['Count','Workday','7 Day'], axis=1)
may24_df = may24_df.rename(columns={may24_df.columns[0]: 'hour'})  # rename first column to 'hour'
may24_df_long = pd.melt(may24_df, id_vars='hour', var_name='date', value_name='value')
may24_df_long['datetime'] = pd.to_datetime(may24_df_long['date'].astype(str) + ' ' + may24_df_long['hour'].astype(str))
may24_df_long = may24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
may24_df_long.head()

may23_df = pd.read_csv("../mydata/traffic/counter 2/r2-lgv-data/may-23.csv")
may23_df=may23_df.drop(['Count','Workday','7 Day'], axis=1)
may23_df = may23_df.rename(columns={may23_df.columns[0]: 'hour'})  # rename first column to 'hour'
may23_df_long = pd.melt(may23_df, id_vars='hour', var_name='date', value_name='value')
may23_df_long['datetime'] = pd.to_datetime(may23_df_long['date'].astype(str) + ' ' + may23_df_long['hour'].astype(str))
may23_df_long = may23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
may23_df_long.head()


apr24_df = pd.read_csv("../mydata/traffic/counter 2/r2-lgv-data/apr-24.csv")
apr24_df=apr24_df.drop(['Count','Workday','7 Day'], axis=1)
apr24_df = apr24_df.rename(columns={apr24_df.columns[0]: 'hour'})  # rename first column to 'hour'
apr24_df_long = pd.melt(apr24_df, id_vars='hour', var_name='date', value_name='value')
apr24_df_long['datetime'] = pd.to_datetime(apr24_df_long['date'].astype(str) + ' ' + apr24_df_long['hour'].astype(str))
apr24_df_long = apr24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
apr24_df_long.head()

apr23_df = pd.read_csv("../mydata/traffic/counter 2/r2-lgv-data/apr-23.csv")
apr23_df=apr23_df.drop(['Count','Workday','7 Day'], axis=1)
apr23_df = apr23_df.rename(columns={apr23_df.columns[0]: 'hour'})  # rename first column to 'hour'
apr23_df_long = pd.melt(apr23_df, id_vars='hour', var_name='date', value_name='value')
apr23_df_long['datetime'] = pd.to_datetime(apr23_df_long['date'].astype(str) + ' ' + apr23_df_long['hour'].astype(str))
apr23_df_long = apr23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
apr23_df_long.head()

mar24_df = pd.read_csv("../mydata/traffic/counter 2/r2-lgv-data/mar-24.csv")
mar24_df=mar24_df.drop(['Count','Workday','7 Day'], axis=1)
mar24_df =mar24_df.rename(columns={mar24_df.columns[0]: 'hour'})  # rename first column to 'hour'
mar24_df_long = pd.melt(mar24_df, id_vars='hour', var_name='date', value_name='value')
mar24_df_long['datetime'] = pd.to_datetime(mar24_df_long['date'].astype(str) + ' ' + mar24_df_long['hour'].astype(str))
mar24_df_long = mar24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
mar24_df_long.head()

mar23_df = pd.read_csv("../mydata/traffic/counter 2/r2-lgv-data/mar-23.csv")
mar23_df=mar23_df.drop(['Count','Workday','7 Day'], axis=1)
mar23_df =mar23_df.rename(columns={mar23_df.columns[0]: 'hour'})  # rename first column to 'hour'
mar23_df_long = pd.melt(mar23_df, id_vars='hour', var_name='date', value_name='value')
mar23_df_long['datetime'] = pd.to_datetime(mar23_df_long['date'].astype(str) + ' ' + mar23_df_long['hour'].astype(str))
mar23_df_long = mar23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
mar23_df_long.head()

feb24_df = pd.read_csv("../mydata/traffic/counter 2/r2-lgv-data/feb-24.csv")
feb24_df=feb24_df.drop(['Count','Workday','7 Day'], axis=1)
feb24_df =feb24_df.rename(columns={feb24_df.columns[0]: 'hour'})  # rename first column to 'hour'
feb24_df_long = pd.melt(feb24_df, id_vars='hour', var_name='date', value_name='value')
feb24_df_long['datetime'] = pd.to_datetime(feb24_df_long['date'].astype(str) + ' ' + feb24_df_long['hour'].astype(str))
feb24_df_long = feb24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
feb24_df_long.head()

feb23_df = pd.read_csv("../mydata/traffic/counter 2/r2-lgv-data/feb-23.csv")
feb23_df=feb23_df.drop(['Count','Workday','7 Day'], axis=1)
feb23_df =feb23_df.rename(columns={feb23_df.columns[0]: 'hour'})  # rename first column to 'hour'
feb23_df_long = pd.melt(feb23_df, id_vars='hour', var_name='date', value_name='value')
feb23_df_long['datetime'] = pd.to_datetime(feb23_df_long['date'].astype(str) + ' ' + feb23_df_long['hour'].astype(str))
feb23_df_long = feb23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
feb23_df_long.head()

jan24_df = pd.read_csv("../mydata/traffic/counter 2/r2-lgv-data/jan-24.csv")
jan24_df=jan24_df.drop(['Count','Workday','7 Day'], axis=1)
jan24_df =jan24_df.rename(columns={jan24_df.columns[0]: 'hour'})  # rename first column to 'hour'
jan24_df_long = pd.melt(jan24_df, id_vars='hour', var_name='date', value_name='value')
jan24_df_long['datetime'] = pd.to_datetime(jan24_df_long['date'].astype(str) + ' ' + jan24_df_long['hour'].astype(str))
jan24_df_long = jan24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
jan24_df_long.head()

jan23_df = pd.read_csv("../mydata/traffic/counter 2/r2-lgv-data/jan-23.csv")
jan23_df=jan23_df.drop(['Count','Workday','7 Day'], axis=1)
jan23_df =jan23_df.rename(columns={jan23_df.columns[0]: 'hour'})  # rename first column to 'hour'
jan23_df_long = pd.melt(jan23_df, id_vars='hour', var_name='date', value_name='value')
jan23_df_long['datetime'] = pd.to_datetime(jan23_df_long['date'].astype(str) + ' ' + jan23_df_long['hour'].astype(str))
jan23_df_long = jan23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
jan23_df_long.head()


dec23_df = pd.read_csv("../mydata/traffic/counter 2/r2-lgv-data/dec-23.csv")
dec23_df=dec23_df.drop(['Count','Workday','7 Day'], axis=1)
dec23_df =dec23_df.rename(columns={dec23_df.columns[0]: 'hour'})  # rename first column to 'hour'
dec23_df_long = pd.melt(dec23_df, id_vars='hour', var_name='date', value_name='value')
dec23_df_long['datetime'] = pd.to_datetime(dec23_df_long['date'].astype(str) + ' ' + dec23_df_long['hour'].astype(str))
dec23_df_long = dec23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
dec23_df_long.head()

dec24_df = pd.read_csv("../mydata/traffic/counter 2/r2-lgv-data/dec-24.csv")
dec24_df=dec24_df.drop(['Count','Workday','7 Day'], axis=1)
dec24_df =dec24_df.rename(columns={dec24_df.columns[0]: 'hour'})  # rename first column to 'hour'
dec24_df_long = pd.melt(dec24_df, id_vars='hour', var_name='date', value_name='value')
dec24_df_long['datetime'] = pd.to_datetime(dec24_df_long['date'].astype(str) + ' ' + dec24_df_long['hour'].astype(str))
dec24_df_long = dec24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
dec24_df_long.head()


nov23_df = pd.read_csv("../mydata/traffic/counter 2/r2-lgv-data/nov-23.csv")
nov23_df=nov23_df.drop(['Count','Workday','7 Day'], axis=1)
nov23_df =nov23_df.rename(columns={nov23_df.columns[0]: 'hour'})  # rename first column to 'hour'
nov23_df_long = pd.melt(nov23_df, id_vars='hour', var_name='date', value_name='value')
nov23_df_long['datetime'] = pd.to_datetime(nov23_df_long['date'].astype(str) + ' ' + nov23_df_long['hour'].astype(str))
nov23_df_long = nov23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
nov23_df_long.head()

nov24_df = pd.read_csv("../mydata/traffic/counter 2/r2-lgv-data/nov-24.csv")
nov24_df=nov24_df.drop(['Count','Workday','7 Day'], axis=1)
nov24_df =nov24_df.rename(columns={nov24_df.columns[0]: 'hour'})  # rename first column to 'hour'
nov24_df_long = pd.melt(nov24_df, id_vars='hour', var_name='date', value_name='value')
nov24_df_long['datetime'] = pd.to_datetime(nov24_df_long['date'].astype(str) + ' ' + nov24_df_long['hour'].astype(str))
nov24_df_long = nov24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
nov24_df_long.head()



oct23_df = pd.read_csv("../mydata/traffic/counter 2/r2-lgv-data/oct-23.csv")
oct23_df=oct23_df.drop(['Count','Workday','7 Day'], axis=1)
oct23_df =oct23_df.rename(columns={oct23_df.columns[0]: 'hour'})  # rename first column to 'hour'
oct23_df_long = pd.melt(oct23_df, id_vars='hour', var_name='date', value_name='value')
oct23_df_long['datetime'] = pd.to_datetime(oct23_df_long['date'].astype(str) + ' ' + oct23_df_long['hour'].astype(str))
oct23_df_long = oct23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
oct23_df_long.head()

oct24_df = pd.read_csv("../mydata/traffic/counter 2/r2-lgv-data/oct-24.csv")
oct24_df=oct24_df.drop(['Count','Workday','7 Day'], axis=1)
oct24_df =oct24_df.rename(columns={oct24_df.columns[0]: 'hour'})  # rename first column to 'hour'
oct24_df_long = pd.melt(oct24_df, id_vars='hour', var_name='date', value_name='value')
oct24_df_long['datetime'] = pd.to_datetime(oct24_df_long['date'].astype(str) + ' ' + oct24_df_long['hour'].astype(str))
oct24_df_long = oct24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
oct24_df_long.head()


sep23_df = pd.read_csv("../mydata/traffic/counter 2/r2-lgv-data/sep-23.csv")
sep23_df=sep23_df.drop(['Count','Workday','7 Day'], axis=1)
sep23_df =sep23_df.rename(columns={sep23_df.columns[0]: 'hour'})  # rename first column to 'hour'
sep23_df_long = pd.melt(sep23_df, id_vars='hour', var_name='date', value_name='value')
sep23_df_long['datetime'] = pd.to_datetime(sep23_df_long['date'].astype(str) + ' ' + sep23_df_long['hour'].astype(str))
sep23_df_long = sep23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
sep23_df_long.head()

sep24_df = pd.read_csv("../mydata/traffic/counter 2/r2-lgv-data/sep-24.csv")
sep24_df=sep24_df.drop(['Count','Workday','7 Day'], axis=1)
sep24_df =sep24_df.rename(columns={sep24_df.columns[0]: 'hour'})  # rename first column to 'hour'
sep24_df_long = pd.melt(sep24_df, id_vars='hour', var_name='date', value_name='value')
sep24_df_long['datetime'] = pd.to_datetime(sep24_df_long['date'].astype(str) + ' ' + sep24_df_long['hour'].astype(str))
sep24_df_long = sep24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
sep24_df_long.head()


aug23_df = pd.read_csv("../mydata/traffic/counter 2/r2-lgv-data/aug-23.csv")
aug23_df=aug23_df.drop(['Count','Workday','7 Day'], axis=1)
aug23_df =aug23_df.rename(columns={aug23_df.columns[0]: 'hour'})  # rename first column to 'hour'
aug23_df_long = pd.melt(aug23_df, id_vars='hour', var_name='date', value_name='value')
aug23_df_long['datetime'] = pd.to_datetime(aug23_df_long['date'].astype(str) + ' ' + aug23_df_long['hour'].astype(str))
aug23_df_long = aug23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
aug23_df_long.head()

aug24_df = pd.read_csv("../mydata/traffic/counter 2/r2-lgv-data/aug-24.csv")
aug24_df=aug24_df.drop(['Count','Workday','7 Day'], axis=1)
aug24_df =aug24_df.rename(columns={aug24_df.columns[0]: 'hour'})  # rename first column to 'hour'
aug24_df_long = pd.melt(aug24_df, id_vars='hour', var_name='date', value_name='value')
aug24_df_long['datetime'] = pd.to_datetime(aug24_df_long['date'].astype(str) + ' ' + aug24_df_long['hour'].astype(str))
aug24_df_long = aug24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
aug24_df_long.head()


jul23_df = pd.read_csv("../mydata/traffic/counter 2/r2-lgv-data/jul-23.csv")
jul23_df=jul23_df.drop(['Count','Workday','7 Day'], axis=1)
jul23_df =jul23_df.rename(columns={jul23_df.columns[0]: 'hour'})  # rename first column to 'hour'
jul23_df_long = pd.melt(jul23_df, id_vars='hour', var_name='date', value_name='value')
jul23_df_long['datetime'] = pd.to_datetime(jul23_df_long['date'].astype(str) + ' ' + jul23_df_long['hour'].astype(str))
jul23_df_long = jul23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
jul23_df_long.head()

jul24_df = pd.read_csv("../mydata/traffic/counter 2/r2-lgv-data/jul-24.csv")
jul24_df=jul24_df.drop(['Count','Workday','7 Day'], axis=1)
jul24_df =jul24_df.rename(columns={jul24_df.columns[0]: 'hour'})  # rename first column to 'hour'
jul24_df_long = pd.melt(jul24_df, id_vars='hour', var_name='date', value_name='value')
jul24_df_long['datetime'] = pd.to_datetime(jul24_df_long['date'].astype(str) + ' ' + jul24_df_long['hour'].astype(str))
jul24_df_long = jul24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
jul24_df_long.head()
# Out:
#              datetime  value
# 0 2024-07-01 00:00:00     16
# 1 2024-07-01 01:00:00      8
# 2 2024-07-01 02:00:00     10
# 3 2024-07-01 03:00:00     20
# 4 2024-07-01 04:00:00     28

# %%
# combined_df = pd.concat([may24_df_long, jun24_df_long], ignore_index=True)
# combined_df = pd.concat([apr24_df_long, combined_df], ignore_index=True)
# combined_df = pd.concat([mar24_df_long, combined_df], ignore_index=True)
# combined_df = pd.concat([feb24_df_long, combined_df], ignore_index=True)
# combined_df = pd.concat([jan24_df_long, combined_df], ignore_index=True)
# combined_df = pd.concat([dec23_df_long, combined_df], ignore_index=True)
# combined_df = pd.concat([nov23_df_long, combined_df], ignore_index=True)
# combined_df = pd.concat([oct23_df_long, combined_df], ignore_index=True)
# combined_df = pd.concat([sep23_df_long, combined_df], ignore_index=True)
# combined_df = pd.concat([aug23_df_long, combined_df], ignore_index=True)
# combined_df1 = pd.concat([jul23_df_long, combined_df], ignore_index=True)
# combined_df1.head()


combined_df = pd.concat([nov24_df_long, dec24_df_long], ignore_index=True)
combined_df = pd.concat([oct24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([sep24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([aug24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([jul24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([jun24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([may24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([apr24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([mar24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([feb24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([jan24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([dec23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([nov23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([oct23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([sep23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([aug23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([jul23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([jun23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([may23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([apr23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([mar23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([feb23_df_long, combined_df], ignore_index=True)
combined_df1 = pd.concat([jan23_df_long, combined_df], ignore_index=True)
combined_df1.head()
# Out:
#              datetime  value
# 0 2023-01-01 00:00:00   32.0
# 1 2023-01-01 01:00:00   22.0
# 2 2023-01-01 02:00:00   34.0
# 3 2023-01-01 03:00:00   26.0
# 4 2023-01-01 04:00:00    3.0

# %%
combined_df1.to_csv('../mydata/traffic/counter 2/lgv_count_23_24_complete.csv')
lgv_r2=pd.read_csv('../mydata/traffic/counter 2/lgv_count_23_24_complete.csv')

# %%
lgv_r2=pd.read_csv('../mydata/traffic/counter 2/lgv_count_23_24_complete.csv')

# %%
len(lgv_r2)
# Out:
# 17544

# %%
lgv_r1=pd.read_csv('../mydata/traffic/counter 1/lgv_count_23_24_complete.csv')

# %%
len(lgv_r1)
# Out:
# 17544

# %%
lgv_r1.dropna(subset=['value'], inplace=True)

# %%
lgv_r2.dropna(subset=['value'], inplace=True)

# %% [markdown]
# HGV 1

# %%
jun24_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-art/jun-24.csv")
jun24_df=jun24_df.drop(['Count','Workday','7 Day'], axis=1)
jun24_df = jun24_df.rename(columns={jun24_df.columns[0]: 'hour'})  # rename first column to 'hour'
jun24_df_long = pd.melt(jun24_df, id_vars='hour', var_name='date', value_name='value')
jun24_df_long['datetime'] = pd.to_datetime(jun24_df_long['date'].astype(str) + ' ' + jun24_df_long['hour'].astype(str))
jun24_df_long = jun24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
jun24_df_long.head()

jun23_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-art/jun-23.csv")
jun23_df=jun23_df.drop(['Count','Workday','7 Day'], axis=1)
jun23_df = jun23_df.rename(columns={jun23_df.columns[0]: 'hour'})  # rename first column to 'hour'
jun23_df_long = pd.melt(jun23_df, id_vars='hour', var_name='date', value_name='value')
jun23_df_long['datetime'] = pd.to_datetime(jun23_df_long['date'].astype(str) + ' ' + jun23_df_long['hour'].astype(str))
jun23_df_long = jun23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
jun23_df_long.head()


may24_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-art/may-24.csv")
may24_df=may24_df.drop(['Count','Workday','7 Day'], axis=1)
may24_df = may24_df.rename(columns={may24_df.columns[0]: 'hour'})  # rename first column to 'hour'
may24_df_long = pd.melt(may24_df, id_vars='hour', var_name='date', value_name='value')
may24_df_long['datetime'] = pd.to_datetime(may24_df_long['date'].astype(str) + ' ' + may24_df_long['hour'].astype(str))
may24_df_long = may24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
may24_df_long.head()

may23_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-art/may-23.csv")
may23_df=may23_df.drop(['Count','Workday','7 Day'], axis=1)
may23_df = may23_df.rename(columns={may23_df.columns[0]: 'hour'})  # rename first column to 'hour'
may23_df_long = pd.melt(may23_df, id_vars='hour', var_name='date', value_name='value')
may23_df_long['datetime'] = pd.to_datetime(may23_df_long['date'].astype(str) + ' ' + may23_df_long['hour'].astype(str))
may23_df_long = may23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
may23_df_long.head()

apr24_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-art/apr-24.csv")
apr24_df=apr24_df.drop(['Count','Workday','7 Day'], axis=1)
apr24_df = apr24_df.rename(columns={apr24_df.columns[0]: 'hour'})  # rename first column to 'hour'
apr24_df_long = pd.melt(apr24_df, id_vars='hour', var_name='date', value_name='value')
apr24_df_long['datetime'] = pd.to_datetime(apr24_df_long['date'].astype(str) + ' ' + apr24_df_long['hour'].astype(str))
apr24_df_long = apr24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
apr24_df_long.head()

apr23_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-art/apr-23.csv")
apr23_df=apr23_df.drop(['Count','Workday','7 Day'], axis=1)
apr23_df = apr23_df.rename(columns={apr23_df.columns[0]: 'hour'})  # rename first column to 'hour'
apr23_df_long = pd.melt(apr23_df, id_vars='hour', var_name='date', value_name='value')
apr23_df_long['datetime'] = pd.to_datetime(apr23_df_long['date'].astype(str) + ' ' + apr23_df_long['hour'].astype(str))
apr23_df_long = apr23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
apr23_df_long.head()

mar24_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-art/mar-24.csv")
mar24_df=mar24_df.drop(['Count','Workday','7 Day'], axis=1)
mar24_df =mar24_df.rename(columns={mar24_df.columns[0]: 'hour'})  # rename first column to 'hour'
mar24_df_long = pd.melt(mar24_df, id_vars='hour', var_name='date', value_name='value')
mar24_df_long['datetime'] = pd.to_datetime(mar24_df_long['date'].astype(str) + ' ' + mar24_df_long['hour'].astype(str))
mar24_df_long = mar24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
mar24_df_long.head()

mar23_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-art/mar-23.csv")
mar23_df=mar23_df.drop(['Count','Workday','7 Day'], axis=1)
mar23_df =mar23_df.rename(columns={mar23_df.columns[0]: 'hour'})  # rename first column to 'hour'
mar23_df_long = pd.melt(mar23_df, id_vars='hour', var_name='date', value_name='value')
mar23_df_long['datetime'] = pd.to_datetime(mar23_df_long['date'].astype(str) + ' ' + mar23_df_long['hour'].astype(str))
mar23_df_long = mar23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
mar23_df_long.head()


feb24_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-art/feb-24.csv")
feb24_df=feb24_df.drop(['Count','Workday','7 Day'], axis=1)
feb24_df =feb24_df.rename(columns={feb24_df.columns[0]: 'hour'})  # rename first column to 'hour'
feb24_df_long = pd.melt(feb24_df, id_vars='hour', var_name='date', value_name='value')
feb24_df_long['datetime'] = pd.to_datetime(feb24_df_long['date'].astype(str) + ' ' + feb24_df_long['hour'].astype(str))
feb24_df_long = feb24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
feb24_df_long.head()

feb23_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-art/feb-23.csv")
feb23_df=feb23_df.drop(['Count','Workday','7 Day'], axis=1)
feb23_df =feb23_df.rename(columns={feb23_df.columns[0]: 'hour'})  # rename first column to 'hour'
feb23_df_long = pd.melt(feb23_df, id_vars='hour', var_name='date', value_name='value')
feb23_df_long['datetime'] = pd.to_datetime(feb23_df_long['date'].astype(str) + ' ' + feb23_df_long['hour'].astype(str))
feb23_df_long = feb23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
feb23_df_long.head()


jan24_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-art/jan-24.csv")
jan24_df=jan24_df.drop(['Count','Workday','7 Day'], axis=1)
jan24_df =jan24_df.rename(columns={jan24_df.columns[0]: 'hour'})  # rename first column to 'hour'
jan24_df_long = pd.melt(jan24_df, id_vars='hour', var_name='date', value_name='value')
jan24_df_long['datetime'] = pd.to_datetime(jan24_df_long['date'].astype(str) + ' ' + jan24_df_long['hour'].astype(str))
jan24_df_long = jan24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
jan24_df_long.head()

jan23_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-art/jan-23.csv")
jan23_df=jan23_df.drop(['Count','Workday','7 Day'], axis=1)
jan23_df =jan23_df.rename(columns={jan23_df.columns[0]: 'hour'})  # rename first column to 'hour'
jan23_df_long = pd.melt(jan23_df, id_vars='hour', var_name='date', value_name='value')
jan23_df_long['datetime'] = pd.to_datetime(jan23_df_long['date'].astype(str) + ' ' + jan23_df_long['hour'].astype(str))
jan23_df_long = jan23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
jan23_df_long.head()

dec23_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-art/dec-23.csv")
dec23_df=dec23_df.drop(['Count','Workday','7 Day'], axis=1)
dec23_df =dec23_df.rename(columns={dec23_df.columns[0]: 'hour'})  # rename first column to 'hour'
dec23_df_long = pd.melt(dec23_df, id_vars='hour', var_name='date', value_name='value')
dec23_df_long['datetime'] = pd.to_datetime(dec23_df_long['date'].astype(str) + ' ' + dec23_df_long['hour'].astype(str))
dec23_df_long = dec23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
dec23_df_long.head()

dec24_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-art/dec-24.csv")
dec24_df=dec24_df.drop(['Count','Workday','7 Day'], axis=1)
dec24_df =dec24_df.rename(columns={dec24_df.columns[0]: 'hour'})  # rename first column to 'hour'
dec24_df_long = pd.melt(dec24_df, id_vars='hour', var_name='date', value_name='value')
dec24_df_long['datetime'] = pd.to_datetime(dec24_df_long['date'].astype(str) + ' ' + dec24_df_long['hour'].astype(str))
dec24_df_long = dec24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
dec24_df_long.head()


nov23_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-art/nov-23.csv")
nov23_df=nov23_df.drop(['Count','Workday','7 Day'], axis=1)
nov23_df =nov23_df.rename(columns={nov23_df.columns[0]: 'hour'})  # rename first column to 'hour'
nov23_df_long = pd.melt(nov23_df, id_vars='hour', var_name='date', value_name='value')
nov23_df_long['datetime'] = pd.to_datetime(nov23_df_long['date'].astype(str) + ' ' + nov23_df_long['hour'].astype(str))
nov23_df_long = nov23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
nov23_df_long.head()

nov24_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-art/nov-24.csv")
nov24_df=nov24_df.drop(['Count','Workday','7 Day'], axis=1)
nov24_df =nov24_df.rename(columns={nov24_df.columns[0]: 'hour'})  # rename first column to 'hour'
nov24_df_long = pd.melt(nov24_df, id_vars='hour', var_name='date', value_name='value')
nov24_df_long['datetime'] = pd.to_datetime(nov24_df_long['date'].astype(str) + ' ' + nov24_df_long['hour'].astype(str))
nov24_df_long = nov24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
nov24_df_long.head()


oct23_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-art/oct-23.csv")
oct23_df=oct23_df.drop(['Count','Workday','7 Day'], axis=1)
oct23_df =oct23_df.rename(columns={oct23_df.columns[0]: 'hour'})  # rename first column to 'hour'
oct23_df_long = pd.melt(oct23_df, id_vars='hour', var_name='date', value_name='value')
oct23_df_long['datetime'] = pd.to_datetime(oct23_df_long['date'].astype(str) + ' ' + oct23_df_long['hour'].astype(str))
oct23_df_long = oct23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
oct23_df_long.head()

oct24_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-art/oct-24.csv")
oct24_df=oct24_df.drop(['Count','Workday','7 Day'], axis=1)
oct24_df =oct24_df.rename(columns={oct24_df.columns[0]: 'hour'})  # rename first column to 'hour'
oct24_df_long = pd.melt(oct24_df, id_vars='hour', var_name='date', value_name='value')
oct24_df_long['datetime'] = pd.to_datetime(oct24_df_long['date'].astype(str) + ' ' + oct24_df_long['hour'].astype(str))
oct24_df_long = oct24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
oct24_df_long.head()


sep23_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-art/sep-23.csv")
sep23_df=sep23_df.drop(['Count','Workday','7 Day'], axis=1)
sep23_df =sep23_df.rename(columns={sep23_df.columns[0]: 'hour'})  # rename first column to 'hour'
sep23_df_long = pd.melt(sep23_df, id_vars='hour', var_name='date', value_name='value')
sep23_df_long['datetime'] = pd.to_datetime(sep23_df_long['date'].astype(str) + ' ' + sep23_df_long['hour'].astype(str))
sep23_df_long = sep23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
sep23_df_long.head()

sep24_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-art/sep-24.csv")
sep24_df=sep24_df.drop(['Count','Workday','7 Day'], axis=1)
sep24_df =sep24_df.rename(columns={sep24_df.columns[0]: 'hour'})  # rename first column to 'hour'
sep24_df_long = pd.melt(sep24_df, id_vars='hour', var_name='date', value_name='value')
sep24_df_long['datetime'] = pd.to_datetime(sep24_df_long['date'].astype(str) + ' ' + sep24_df_long['hour'].astype(str))
sep24_df_long = sep24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
sep24_df_long.head()



aug23_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-art/aug-23.csv")
aug23_df=aug23_df.drop(['Count','Workday','7 Day'], axis=1)
aug23_df =aug23_df.rename(columns={aug23_df.columns[0]: 'hour'})  # rename first column to 'hour'
aug23_df_long = pd.melt(aug23_df, id_vars='hour', var_name='date', value_name='value')
aug23_df_long['datetime'] = pd.to_datetime(aug23_df_long['date'].astype(str) + ' ' + aug23_df_long['hour'].astype(str))
aug23_df_long = aug23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
aug23_df_long.head()

aug24_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-art/aug-24.csv")
aug24_df=aug24_df.drop(['Count','Workday','7 Day'], axis=1)
aug24_df =aug24_df.rename(columns={aug24_df.columns[0]: 'hour'})  # rename first column to 'hour'
aug24_df_long = pd.melt(aug24_df, id_vars='hour', var_name='date', value_name='value')
aug24_df_long['datetime'] = pd.to_datetime(aug24_df_long['date'].astype(str) + ' ' + aug24_df_long['hour'].astype(str))
aug24_df_long = aug24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
aug24_df_long.head()


jul23_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-art/jul-23.csv")
jul23_df=jul23_df.drop(['Count','Workday','7 Day'], axis=1)
jul23_df =jul23_df.rename(columns={jul23_df.columns[0]: 'hour'})  # rename first column to 'hour'
jul23_df_long = pd.melt(jul23_df, id_vars='hour', var_name='date', value_name='value')
jul23_df_long['datetime'] = pd.to_datetime(jul23_df_long['date'].astype(str) + ' ' + jul23_df_long['hour'].astype(str))
jul23_df_long = jul23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
jul23_df_long.head()

jul24_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-art/jul-24.csv")
jul24_df=jul24_df.drop(['Count','Workday','7 Day'], axis=1)
jul24_df =jul24_df.rename(columns={jul24_df.columns[0]: 'hour'})  # rename first column to 'hour'
jul24_df_long = pd.melt(jul24_df, id_vars='hour', var_name='date', value_name='value')
jul24_df_long['datetime'] = pd.to_datetime(jul24_df_long['date'].astype(str) + ' ' + jul24_df_long['hour'].astype(str))
jul24_df_long = jul24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
jul24_df_long.head()
# Out:
#              datetime  value
# 0 2024-07-01 00:00:00      3
# 1 2024-07-01 01:00:00      2
# 2 2024-07-01 02:00:00      5
# 3 2024-07-01 03:00:00      8
# 4 2024-07-01 04:00:00     10

# %%
# combined_df = pd.concat([may24_df_long, jun24_df_long], ignore_index=True)
# combined_df = pd.concat([apr24_df_long, combined_df], ignore_index=True)
# combined_df = pd.concat([mar24_df_long, combined_df], ignore_index=True)
# combined_df = pd.concat([feb24_df_long, combined_df], ignore_index=True)
# combined_df = pd.concat([jan24_df_long, combined_df], ignore_index=True)
# combined_df = pd.concat([dec23_df_long, combined_df], ignore_index=True)
# combined_df = pd.concat([nov23_df_long, combined_df], ignore_index=True)
# combined_df = pd.concat([oct23_df_long, combined_df], ignore_index=True)
# combined_df = pd.concat([sep23_df_long, combined_df], ignore_index=True)
# combined_df = pd.concat([aug23_df_long, combined_df], ignore_index=True)
# combined_df1 = pd.concat([jul23_df_long, combined_df], ignore_index=True)
# combined_df1.head()

combined_df = pd.concat([nov24_df_long, dec24_df_long], ignore_index=True)
combined_df = pd.concat([oct24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([sep24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([aug24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([jul24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([jun24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([may24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([apr24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([mar24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([feb24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([jan24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([dec23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([nov23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([oct23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([sep23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([aug23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([jul23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([jun23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([may23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([apr23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([mar23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([feb23_df_long, combined_df], ignore_index=True)
combined_df1 = pd.concat([jan23_df_long, combined_df], ignore_index=True)
combined_df1.head()
# Out:
#              datetime  value
# 0 2023-01-01 00:00:00    0.0
# 1 2023-01-01 01:00:00    0.0
# 2 2023-01-01 02:00:00    1.0
# 3 2023-01-01 03:00:00    0.0
# 4 2023-01-01 04:00:00    1.0

# %% [markdown]
# HGV 2

# %%
jun24_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-rig/jun-24.csv")
jun24_df=jun24_df.drop(['Count','Workday','7 Day'], axis=1)
jun24_df = jun24_df.rename(columns={jun24_df.columns[0]: 'hour'})  # rename first column to 'hour'
jun24_df_long = pd.melt(jun24_df, id_vars='hour', var_name='date', value_name='value')
jun24_df_long['datetime'] = pd.to_datetime(jun24_df_long['date'].astype(str) + ' ' + jun24_df_long['hour'].astype(str))
jun24_df_long = jun24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
jun24_df_long.head()

jun23_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-rig/jun-23.csv")
jun23_df=jun23_df.drop(['Count','Workday','7 Day'], axis=1)
jun23_df = jun23_df.rename(columns={jun23_df.columns[0]: 'hour'})  # rename first column to 'hour'
jun23_df_long = pd.melt(jun23_df, id_vars='hour', var_name='date', value_name='value')
jun23_df_long['datetime'] = pd.to_datetime(jun23_df_long['date'].astype(str) + ' ' + jun23_df_long['hour'].astype(str))
jun23_df_long = jun23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
jun23_df_long.head()

may24_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-rig/may-24.csv")
may24_df=may24_df.drop(['Count','Workday','7 Day'], axis=1)
may24_df = may24_df.rename(columns={may24_df.columns[0]: 'hour'})  # rename first column to 'hour'
may24_df_long = pd.melt(may24_df, id_vars='hour', var_name='date', value_name='value')
may24_df_long['datetime'] = pd.to_datetime(may24_df_long['date'].astype(str) + ' ' + may24_df_long['hour'].astype(str))
may24_df_long = may24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
may24_df_long.head()

may23_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-rig/may-23.csv")
may23_df=may23_df.drop(['Count','Workday','7 Day'], axis=1)
may23_df = may23_df.rename(columns={may23_df.columns[0]: 'hour'})  # rename first column to 'hour'
may23_df_long = pd.melt(may23_df, id_vars='hour', var_name='date', value_name='value')
may23_df_long['datetime'] = pd.to_datetime(may23_df_long['date'].astype(str) + ' ' + may23_df_long['hour'].astype(str))
may23_df_long = may23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
may23_df_long.head()

apr24_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-rig/apr-24.csv")
apr24_df=apr24_df.drop(['Count','Workday','7 Day'], axis=1)
apr24_df = apr24_df.rename(columns={apr24_df.columns[0]: 'hour'})  # rename first column to 'hour'
apr24_df_long = pd.melt(apr24_df, id_vars='hour', var_name='date', value_name='value')
apr24_df_long['datetime'] = pd.to_datetime(apr24_df_long['date'].astype(str) + ' ' + apr24_df_long['hour'].astype(str))
apr24_df_long = apr24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
apr24_df_long.head()

apr23_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-rig/apr-23.csv")
apr23_df=apr23_df.drop(['Count','Workday','7 Day'], axis=1)
apr23_df = apr23_df.rename(columns={apr23_df.columns[0]: 'hour'})  # rename first column to 'hour'
apr23_df_long = pd.melt(apr23_df, id_vars='hour', var_name='date', value_name='value')
apr23_df_long['datetime'] = pd.to_datetime(apr23_df_long['date'].astype(str) + ' ' + apr23_df_long['hour'].astype(str))
apr23_df_long = apr23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
apr23_df_long.head()

mar24_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-rig/mar-24.csv")
mar24_df=mar24_df.drop(['Count','Workday','7 Day'], axis=1)
mar24_df =mar24_df.rename(columns={mar24_df.columns[0]: 'hour'})  # rename first column to 'hour'
mar24_df_long = pd.melt(mar24_df, id_vars='hour', var_name='date', value_name='value')
mar24_df_long['datetime'] = pd.to_datetime(mar24_df_long['date'].astype(str) + ' ' + mar24_df_long['hour'].astype(str))
mar24_df_long = mar24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
mar24_df_long.head()

mar23_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-rig/mar-23.csv")
mar23_df=mar23_df.drop(['Count','Workday','7 Day'], axis=1)
mar23_df =mar23_df.rename(columns={mar23_df.columns[0]: 'hour'})  # rename first column to 'hour'
mar23_df_long = pd.melt(mar23_df, id_vars='hour', var_name='date', value_name='value')
mar23_df_long['datetime'] = pd.to_datetime(mar23_df_long['date'].astype(str) + ' ' + mar23_df_long['hour'].astype(str))
mar23_df_long = mar23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
mar23_df_long.head()


feb24_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-rig/feb-24.csv")
feb24_df=feb24_df.drop(['Count','Workday','7 Day'], axis=1)
feb24_df =feb24_df.rename(columns={feb24_df.columns[0]: 'hour'})  # rename first column to 'hour'
feb24_df_long = pd.melt(feb24_df, id_vars='hour', var_name='date', value_name='value')
feb24_df_long['datetime'] = pd.to_datetime(feb24_df_long['date'].astype(str) + ' ' + feb24_df_long['hour'].astype(str))
feb24_df_long = feb24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
feb24_df_long.head()

feb23_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-rig/feb-23.csv")
feb23_df=feb23_df.drop(['Count','Workday','7 Day'], axis=1)
feb23_df =feb23_df.rename(columns={feb23_df.columns[0]: 'hour'})  # rename first column to 'hour'
feb23_df_long = pd.melt(feb23_df, id_vars='hour', var_name='date', value_name='value')
feb23_df_long['datetime'] = pd.to_datetime(feb23_df_long['date'].astype(str) + ' ' + feb23_df_long['hour'].astype(str))
feb23_df_long = feb23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
feb23_df_long.head()

jan24_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-rig/jan-24.csv")
jan24_df=jan24_df.drop(['Count','Workday','7 Day'], axis=1)
jan24_df =jan24_df.rename(columns={jan24_df.columns[0]: 'hour'})  # rename first column to 'hour'
jan24_df_long = pd.melt(jan24_df, id_vars='hour', var_name='date', value_name='value')
jan24_df_long['datetime'] = pd.to_datetime(jan24_df_long['date'].astype(str) + ' ' + jan24_df_long['hour'].astype(str))
jan24_df_long = jan24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
jan24_df_long.head()

jan23_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-rig/jan-23.csv")
jan23_df=jan23_df.drop(['Count','Workday','7 Day'], axis=1)
jan23_df =jan23_df.rename(columns={jan23_df.columns[0]: 'hour'})  # rename first column to 'hour'
jan23_df_long = pd.melt(jan23_df, id_vars='hour', var_name='date', value_name='value')
jan23_df_long['datetime'] = pd.to_datetime(jan23_df_long['date'].astype(str) + ' ' + jan23_df_long['hour'].astype(str))
jan23_df_long = jan23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
jan23_df_long.head()

dec23_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-rig/dec-23.csv")
dec23_df=dec23_df.drop(['Count','Workday','7 Day'], axis=1)
dec23_df =dec23_df.rename(columns={dec23_df.columns[0]: 'hour'})  # rename first column to 'hour'
dec23_df_long = pd.melt(dec23_df, id_vars='hour', var_name='date', value_name='value')
dec23_df_long['datetime'] = pd.to_datetime(dec23_df_long['date'].astype(str) + ' ' + dec23_df_long['hour'].astype(str))
dec23_df_long = dec23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
dec23_df_long.head()

dec24_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-rig/dec-24.csv")
dec24_df=dec24_df.drop(['Count','Workday','7 Day'], axis=1)
dec24_df =dec24_df.rename(columns={dec24_df.columns[0]: 'hour'})  # rename first column to 'hour'
dec24_df_long = pd.melt(dec24_df, id_vars='hour', var_name='date', value_name='value')
dec24_df_long['datetime'] = pd.to_datetime(dec24_df_long['date'].astype(str) + ' ' + dec24_df_long['hour'].astype(str))
dec24_df_long = dec24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
dec24_df_long.head()

nov23_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-rig/nov-23.csv")
nov23_df=nov23_df.drop(['Count','Workday','7 Day'], axis=1)
nov23_df =nov23_df.rename(columns={nov23_df.columns[0]: 'hour'})  # rename first column to 'hour'
nov23_df_long = pd.melt(nov23_df, id_vars='hour', var_name='date', value_name='value')
nov23_df_long['datetime'] = pd.to_datetime(nov23_df_long['date'].astype(str) + ' ' + nov23_df_long['hour'].astype(str))
nov23_df_long = nov23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
nov23_df_long.head()

nov24_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-rig/nov-24.csv")
nov24_df=nov24_df.drop(['Count','Workday','7 Day'], axis=1)
nov24_df =nov24_df.rename(columns={nov24_df.columns[0]: 'hour'})  # rename first column to 'hour'
nov24_df_long = pd.melt(nov24_df, id_vars='hour', var_name='date', value_name='value')
nov24_df_long['datetime'] = pd.to_datetime(nov24_df_long['date'].astype(str) + ' ' + nov24_df_long['hour'].astype(str))
nov24_df_long = nov24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
nov24_df_long.head()


oct23_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-rig/oct-23.csv")
oct23_df=oct23_df.drop(['Count','Workday','7 Day'], axis=1)
oct23_df =oct23_df.rename(columns={oct23_df.columns[0]: 'hour'})  # rename first column to 'hour'
oct23_df_long = pd.melt(oct23_df, id_vars='hour', var_name='date', value_name='value')
oct23_df_long['datetime'] = pd.to_datetime(oct23_df_long['date'].astype(str) + ' ' + oct23_df_long['hour'].astype(str))
oct23_df_long = oct23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
oct23_df_long.head()

oct24_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-rig/oct-24.csv")
oct24_df=oct24_df.drop(['Count','Workday','7 Day'], axis=1)
oct24_df =oct24_df.rename(columns={oct24_df.columns[0]: 'hour'})  # rename first column to 'hour'
oct24_df_long = pd.melt(oct24_df, id_vars='hour', var_name='date', value_name='value')
oct24_df_long['datetime'] = pd.to_datetime(oct24_df_long['date'].astype(str) + ' ' + oct24_df_long['hour'].astype(str))
oct24_df_long = oct24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
oct24_df_long.head()

sep23_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-rig/sep-23.csv")
sep23_df=sep23_df.drop(['Count','Workday','7 Day'], axis=1)
sep23_df =sep23_df.rename(columns={sep23_df.columns[0]: 'hour'})  # rename first column to 'hour'
sep23_df_long = pd.melt(sep23_df, id_vars='hour', var_name='date', value_name='value')
sep23_df_long['datetime'] = pd.to_datetime(sep23_df_long['date'].astype(str) + ' ' + sep23_df_long['hour'].astype(str))
sep23_df_long = sep23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
sep23_df_long.head()

sep24_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-rig/sep-24.csv")
sep24_df=sep24_df.drop(['Count','Workday','7 Day'], axis=1)
sep24_df =sep24_df.rename(columns={sep24_df.columns[0]: 'hour'})  # rename first column to 'hour'
sep24_df_long = pd.melt(sep24_df, id_vars='hour', var_name='date', value_name='value')
sep24_df_long['datetime'] = pd.to_datetime(sep24_df_long['date'].astype(str) + ' ' + sep24_df_long['hour'].astype(str))
sep24_df_long = sep24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
sep24_df_long.head()


aug23_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-rig/aug-23.csv")
aug23_df=aug23_df.drop(['Count','Workday','7 Day'], axis=1)
aug23_df =aug23_df.rename(columns={aug23_df.columns[0]: 'hour'})  # rename first column to 'hour'
aug23_df_long = pd.melt(aug23_df, id_vars='hour', var_name='date', value_name='value')
aug23_df_long['datetime'] = pd.to_datetime(aug23_df_long['date'].astype(str) + ' ' + aug23_df_long['hour'].astype(str))
aug23_df_long = aug23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
aug23_df_long.head()

aug24_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-rig/aug-24.csv")
aug24_df=aug24_df.drop(['Count','Workday','7 Day'], axis=1)
aug24_df =aug24_df.rename(columns={aug24_df.columns[0]: 'hour'})  # rename first column to 'hour'
aug24_df_long = pd.melt(aug24_df, id_vars='hour', var_name='date', value_name='value')
aug24_df_long['datetime'] = pd.to_datetime(aug24_df_long['date'].astype(str) + ' ' + aug24_df_long['hour'].astype(str))
aug24_df_long = aug24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
aug24_df_long.head()

jul23_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-rig/jul-23.csv")
jul23_df=jul23_df.drop(['Count','Workday','7 Day'], axis=1)
jul23_df =jul23_df.rename(columns={jul23_df.columns[0]: 'hour'})  # rename first column to 'hour'
jul23_df_long = pd.melt(jul23_df, id_vars='hour', var_name='date', value_name='value')
jul23_df_long['datetime'] = pd.to_datetime(jul23_df_long['date'].astype(str) + ' ' + jul23_df_long['hour'].astype(str))
jul23_df_long = jul23_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
jul23_df_long.head()

jul24_df = pd.read_csv("../mydata/traffic/counter 2/r2-hgv-rig/jul-24.csv")
jul24_df=jul24_df.drop(['Count','Workday','7 Day'], axis=1)
jul24_df =jul24_df.rename(columns={jul24_df.columns[0]: 'hour'})  # rename first column to 'hour'
jul24_df_long = pd.melt(jul24_df, id_vars='hour', var_name='date', value_name='value')
jul24_df_long['datetime'] = pd.to_datetime(jul24_df_long['date'].astype(str) + ' ' + jul24_df_long['hour'].astype(str))
jul24_df_long = jul24_df_long[['datetime', 'value']].sort_values('datetime').reset_index(drop=True)
jul24_df_long.head()
# Out:
#              datetime  value
# 0 2024-07-01 00:00:00      0
# 1 2024-07-01 01:00:00      1
# 2 2024-07-01 02:00:00      0
# 3 2024-07-01 03:00:00      1
# 4 2024-07-01 04:00:00      2

# %%
# combined_df = pd.concat([may24_df_long, jun24_df_long], ignore_index=True)
# combined_df = pd.concat([apr24_df_long, combined_df], ignore_index=True)
# combined_df = pd.concat([mar24_df_long, combined_df], ignore_index=True)
# combined_df = pd.concat([feb24_df_long, combined_df], ignore_index=True)
# combined_df = pd.concat([jan24_df_long, combined_df], ignore_index=True)
# combined_df = pd.concat([dec23_df_long, combined_df], ignore_index=True)
# combined_df = pd.concat([nov23_df_long, combined_df], ignore_index=True)
# combined_df = pd.concat([oct23_df_long, combined_df], ignore_index=True)
# combined_df = pd.concat([sep23_df_long, combined_df], ignore_index=True)
# combined_df = pd.concat([aug23_df_long, combined_df], ignore_index=True)
# combined_df2 = pd.concat([jul23_df_long, combined_df], ignore_index=True)
# combined_df2.head()


combined_df = pd.concat([nov24_df_long, dec24_df_long], ignore_index=True)
combined_df = pd.concat([oct24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([sep24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([aug24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([jul24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([jun24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([may24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([apr24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([mar24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([feb24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([jan24_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([dec23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([nov23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([oct23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([sep23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([aug23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([jul23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([jun23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([may23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([apr23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([mar23_df_long, combined_df], ignore_index=True)
combined_df = pd.concat([feb23_df_long, combined_df], ignore_index=True)
combined_df2 = pd.concat([jan23_df_long, combined_df], ignore_index=True)
combined_df2.head()
# Out:
#              datetime  value
# 0 2023-01-01 00:00:00    1.0
# 1 2023-01-01 01:00:00    0.0
# 2 2023-01-01 02:00:00    0.0
# 3 2023-01-01 03:00:00    0.0
# 4 2023-01-01 04:00:00    1.0

# %%
combined_df1[combined_df1['value'].isnull()]['value']=0
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_22236\2481449880.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df1[combined_df1['value'].isnull()]['value']=0

# %%
combined_df2[combined_df2['value'].isnull()]['value']=0
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_22236\847484035.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df2[combined_df2['value'].isnull()]['value']=0

# %%
combined_df1.dropna(subset=['value'], inplace=True)
combined_df2.dropna(subset=['value'],inplace=True)

# %%
combined_df2[combined_df2['value'].isnull()]
# Out:
#                 datetime  value
# 8882 2024-01-06 02:00:00    NaN
# 8883 2024-01-06 03:00:00    NaN
# 8884 2024-01-06 04:00:00    NaN
# 8885 2024-01-06 05:00:00    NaN
# 8886 2024-01-06 06:00:00    NaN
# ...                  ...    ...
# 8960 2024-01-09 08:00:00    NaN
# 8961 2024-01-09 09:00:00    NaN
# 8962 2024-01-09 10:00:00    NaN
# 8963 2024-01-09 11:00:00    NaN
# 8964 2024-01-09 12:00:00    NaN
#
# [76 rows x 2 columns]

# %%
combined_df2['value'] = combined_df2['value'].fillna(0)

# %%
combined_df1[combined_df1['value'].isnull()]
# Out:
# Empty DataFrame
# Columns: [datetime, value]
# Index: []

# %%
combined_df1['value'] = combined_df1['value'].fillna(0)

# %%
combined_df2['value']=combined_df2['value']+combined_df1['value']

# %%
combined_df2.head()
# Out:
#              datetime  value
# 0 2023-01-01 00:00:00    1.0
# 1 2023-01-01 01:00:00    0.0
# 2 2023-01-01 02:00:00    1.0
# 3 2023-01-01 03:00:00    0.0
# 4 2023-01-01 04:00:00    2.0

# %%
combined_df2[combined_df2['value'].isnull()]
# Out:
# Empty DataFrame
# Columns: [datetime, value]
# Index: []

# %%
combined_df2.dropna(subset=['value'],inplace=True)

# %%
lgv_r1[lgv_r1['value'].isnull()]
# Out:
#        Unnamed: 0             datetime  value
# 10921       10921  2024-03-31 01:00:00    NaN

# %%
lgv_r1.head()
# Out:
#    Unnamed: 0             datetime  value
# 0           0  2023-01-01 00:00:00    8.0
# 1           1  2023-01-01 01:00:00   13.0
# 2           2  2023-01-01 02:00:00   10.0
# 3           3  2023-01-01 03:00:00    9.0
# 4           4  2023-01-01 04:00:00    5.0

# %%
combined_df2['value']=combined_df2['value']+lgv_r1['value']

# %%
len(combined_df2)
# Out:
# 17544

# %%
combined_df2.to_csv('../mydata/traffic/counter 2/hgv_count_23_24_complete.csv')
hgv_r2=pd.read_csv('../mydata/traffic/counter 2/hgv_count_23_24_complete.csv')

# %%
hgv_r1=pd.read_csv('../mydata/traffic/counter 1/hgv_count_23_24_complete.csv')
hgv_r2=pd.read_csv('../mydata/traffic/counter 2/hgv_count_23_24_complete.csv')

# %%
car_r1.head(), car_r2.head()
# Out:
# (   Unnamed: 0          datetime  value
#  0           0  01-01-2023 00:00    143
#  1           1  01-01-2023 01:00    206
#  2           2  01-01-2023 02:00    170
#  3           3  01-01-2023 03:00    128
#  4           4  01-01-2023 04:00     48,
#     Unnamed: 0             datetime  value
#  0           0  2023-01-01 00:00:00  458.0
#  1           1  2023-01-01 01:00:00  478.0
#  2           2  2023-01-01 02:00:00  371.0
#  3           3  2023-01-01 03:00:00  304.0
#  4           4  2023-01-01 04:00:00  138.0)

# %%
hgv_r1.head(), hgv_r2.head()
# Out:
# (   Unnamed: 0             datetime  value
#  0           0  2023-01-01 00:00:00    8.0
#  1           1  2023-01-01 01:00:00   13.0
#  2           2  2023-01-01 02:00:00   10.0
#  3           3  2023-01-01 03:00:00    9.0
#  4           4  2023-01-01 04:00:00    5.0,
#     Unnamed: 0             datetime  value
#  0           0  2023-01-01 00:00:00    9.0
#  1           1  2023-01-01 01:00:00   13.0
#  2           2  2023-01-01 02:00:00   11.0
#  3           3  2023-01-01 03:00:00    9.0
#  4           4  2023-01-01 04:00:00    7.0)

# %%
len(car_r1), len(car_r2), len(hgv_r1), len(hgv_r2)
# Out:
# (17543, 17468, 17543, 17544)

# %%
car_r2 = car_r2[car_r2['datetime'] != '2024-03-31 01:00:00']

# %%
hgv_r2=hgv_r2[hgv_r2['datetime'] != '2024-03-31 01:00:00']

# %%
hgv_r2[hgv_r2['value'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, datetime, value]
# Index: []

# %%
full_range = pd.date_range(
    start='2023-01-01 00:00:00',
    end='2024-12-31 23:00:00',
    freq='H',
    tz='Europe/Dublin'
)
full_df = pd.DataFrame({'Timestamp': full_range})

# %%
full_df.head()
# Out:
#                   Timestamp
# 0 2023-01-01 00:00:00+00:00
# 1 2023-01-01 01:00:00+00:00
# 2 2023-01-01 02:00:00+00:00
# 3 2023-01-01 03:00:00+00:00
# 4 2023-01-01 04:00:00+00:00

# %%
hgv_r1.head()
# Out:
#    Unnamed: 0             datetime  value
# 0           0  2023-01-01 00:00:00    8.0
# 1           1  2023-01-01 01:00:00   13.0
# 2           2  2023-01-01 02:00:00   10.0
# 3           3  2023-01-01 03:00:00    9.0
# 4           4  2023-01-01 04:00:00    5.0

# %%
car_r1['datetime'] = pd.to_datetime(car_r1['datetime'], format='%d-%m-%Y %H:%M').dt.tz_localize('Europe/Dublin', ambiguous='NaT', nonexistent='NaT')
car_r2['datetime'] = pd.to_datetime(car_r2['datetime'], format='%Y-%m-%d %H:%M:%S').dt.tz_localize('Europe/Dublin', ambiguous='NaT', nonexistent='NaT')
hgv_r1['datetime'] = pd.to_datetime(hgv_r1['datetime'], format='%Y-%m-%d %H:%M:%S').dt.tz_localize('Europe/Dublin', ambiguous='NaT', nonexistent='NaT')
hgv_r2['datetime'] = pd.to_datetime(hgv_r2['datetime'], format='%Y-%m-%d %H:%M:%S').dt.tz_localize('Europe/Dublin', ambiguous='NaT', nonexistent='NaT')

# %%
car_r1.rename(columns={
    'datetime':'Timestamp'
}, inplace=True)

car_r2.rename(columns={
    'datetime':'Timestamp'
}, inplace=True)

hgv_r1.rename(columns={
    'datetime':'Timestamp'
}, inplace=True)

hgv_r2.rename(columns={
    'datetime':'Timestamp'
}, inplace=True)

# %%
car_r2.tail()
# Out:
#                       Timestamp  Unnamed: 0   value
# 17539 2024-12-31 19:00:00+00:00     17539.0  1159.0
# 17540 2024-12-31 20:00:00+00:00     17540.0   927.0
# 17541 2024-12-31 21:00:00+00:00     17541.0   648.0
# 17542 2024-12-31 22:00:00+00:00     17542.0   481.0
# 17543 2024-12-31 23:00:00+00:00     17543.0   375.0

# %%
car_r1 = full_df.merge(car_r1, on='Timestamp', how='left')
car_r2 = full_df.merge(car_r2, on='Timestamp', how='left')

# %%
len(hgv_r1)
hgv_r1 = full_df.merge(hgv_r1, on='Timestamp', how='left')
hgv_r2 = full_df.merge(hgv_r2, on='Timestamp', how='left')
len(hgv_r1)
# Out:
# 17544

# %%
personal_public_traffic=pd.DataFrame({
    'Timestamp':full_df['Timestamp'],
    'car_r1':car_r1['value'],
    'hgv_r1':hgv_r1['value'],
    'car_r2':car_r2['value'],
    'hgv_r2':hgv_r2['value']
})

# %%
personal_public_traffic.head()
# Out:
#                   Timestamp  car_r1  hgv_r1  car_r2  hgv_r2
# 0 2023-01-01 00:00:00+00:00   143.0     8.0   458.0     9.0
# 1 2023-01-01 01:00:00+00:00   206.0    13.0   478.0    13.0
# 2 2023-01-01 02:00:00+00:00   170.0    10.0   371.0    11.0
# 3 2023-01-01 03:00:00+00:00   128.0     9.0   304.0     9.0
# 4 2023-01-01 04:00:00+00:00    48.0     5.0   138.0     7.0

# %%
personal_public_traffic.to_csv('../mydata/datasets_for_model/personal_public_traff_count.csv')

# %%
from datetime import datetime
start_time_23= datetime.strptime("2023-06-12", "%Y-%m-%d").date()
end_time_23 = datetime.strptime("2023-06-16", "%Y-%m-%d").date()

start_time_24= datetime.strptime("2024-06-10", "%Y-%m-%d").date()
end_time_24 = datetime.strptime("2024-06-14", "%Y-%m-%d").date()

# %%
car_r1['date']=pd.to_datetime(car_r1['datetime']).dt.date
hgv_r1['date']=pd.to_datetime(hgv_r1['datetime']).dt.date

car_before_MT=car_r1[(((car_r1['date']>=start_time_23) & (car_r1['date']<=end_time_23)) |
                     ((car_r1['date']>=start_time_24) & (car_r1['date']<=end_time_24)))]
hgv_before_MT=hgv_r1[(((hgv_r1['date']>=start_time_23) & (hgv_r1['date']<=end_time_23)) |
                     ((hgv_r1['date']>=start_time_24) & (hgv_r1['date']<=end_time_24)))]

# %%
start_time_23= datetime.strptime("2023-07-03", "%Y-%m-%d").date()
end_time_23 = datetime.strptime("2023-07-07", "%Y-%m-%d").date()

start_time_23a= datetime.strptime("2023-08-21", "%Y-%m-%d").date()
end_time_23a = datetime.strptime("2023-08-25", "%Y-%m-%d").date()

start_time_24= datetime.strptime("2024-07-01", "%Y-%m-%d").date()
end_time_24 = datetime.strptime("2024-07-05", "%Y-%m-%d").date()

start_time_24a= datetime.strptime("2024-08-19", "%Y-%m-%d").date()
end_time_24a = datetime.strptime("2024-08-23", "%Y-%m-%d").date()


car_MT=car_r1[(((car_r1['date']>=start_time_23) & (car_r1['date']<=end_time_23)) |
               ((car_r1['date']>=start_time_23a) & (car_r1['date']<=end_time_23a)) |
              ((car_r1['date']>=start_time_24) & (car_r1['date']<=end_time_24)) |
              ((car_r1['date']>=start_time_24a) & (car_r1['date']<=end_time_24a)))]


hgv_MT=hgv_r1[(((hgv_r1['date']>=start_time_23) & (hgv_r1['date']<=end_time_23)) |
               ((hgv_r1['date']>=start_time_23a) & (hgv_r1['date']<=end_time_23a)) |
               ((hgv_r1['date']>=start_time_24a) & (hgv_r1['date']<=end_time_24a)) |
              ((hgv_r1['date']>=start_time_24) & (hgv_r1['date']<=end_time_24)))]

# %%
start_time_23= datetime.strptime("2023-09-04", "%Y-%m-%d").date()
end_time_23 = datetime.strptime("2023-09-08", "%Y-%m-%d").date()

start_time_24= datetime.strptime("2024-09-02", "%Y-%m-%d").date()
end_time_24 = datetime.strptime("2024-09-06", "%Y-%m-%d").date()

car_after_MT=car_r1[(((car_r1['date']>=start_time_23) & (car_r1['date']<=end_time_23)) |
              ((car_r1['date']>=start_time_24) & (car_r1['date']<=end_time_24)))]
hgv_after_MT=hgv_r1[(((hgv_r1['date']>=start_time_23) & (hgv_r1['date']<=end_time_23)) |
              ((hgv_r1['date']>=start_time_24) & (hgv_r1['date']<=end_time_24)))]



# car_after_MT=car_r1[((car_r1['date']>=start_time_23) & (car_r1['date']<=end_time_23))]
# hgv_after_MT=hgv_r1[((hgv_r1['date']>=start_time_23) & (hgv_r1['date']<=end_time_23))]

# %%
car_before_MT['week_type']='School Week 1'
car_MT['week_type']='Summer Break'
car_after_MT['week_type']='School Week 2'


hgv_before_MT['week_type']='School Week 1'
hgv_MT['week_type']='Summer Break'
hgv_after_MT['week_type']='School Week 2'


comb_df1=pd.concat([car_before_MT,car_MT,car_after_MT])
comb_df2=pd.concat([hgv_before_MT,hgv_MT,hgv_after_MT])
comb_df1['hour']=pd.to_datetime(comb_df1['datetime']).dt.hour
comb_df2['hour']=pd.to_datetime(comb_df2['datetime']).dt.hour

comb_df1, comb_df2
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_448100\4050943156.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_before_MT['week_type']='School Week 1'
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_448100\4050943156.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_MT['week_type']='Summer Break'
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_448100\4050943156.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
car_r1['hour']=pd.to_datetime(car_r1['datetime']).dt.hour
car_r1['date']=pd.to_datetime(car_r1['datetime']).dt.date

hgv_r2['hour']=pd.to_datetime(hgv_r2['datetime']).dt.hour
hgv_r2['date']=pd.to_datetime(hgv_r2['datetime']).dt.date

# %%
car_r1['weekdays']=pd.to_datetime(car_r1['datetime']).dt.day_of_week
hgv_r2['weekdays']=pd.to_datetime(hgv_r2['datetime']).dt.day_of_week

car_r1_wday= car_r1[~((car_r1['weekdays']==5) | (car_r1['weekdays']==6))]
hgv_r2_wday=hgv_r2[~((hgv_r2['weekdays']==5) | (hgv_r2['weekdays']==6))]

# %%
car_r1_wday=car_r1_wday[~((car_r1_wday['date']==pd.to_datetime('2024-02-05', format='%Y-%m-%d').date()) |
(car_r1_wday['date']==pd.to_datetime('2024-01-01', format='%Y-%m-%d').date()) |
(car_r1_wday['date']==pd.to_datetime('2024-03-17', format='%Y-%m-%d').date()) |
(car_r1_wday['date']==pd.to_datetime('2024-04-01', format='%Y-%m-%d').date()) |
(car_r1_wday['date']==pd.to_datetime('2024-05-06', format='%Y-%m-%d').date()) |
(car_r1_wday['date']==pd.to_datetime('2024-06-03', format='%Y-%m-%d').date()) |
(car_r1_wday['date']==pd.to_datetime('2024-08-05', format='%Y-%m-%d').date()) |
(car_r1_wday['date']==pd.to_datetime('2024-10-28', format='%Y-%m-%d').date()) |
(car_r1_wday['date']==pd.to_datetime('2024-12-25', format='%Y-%m-%d').date()) |
(car_r1_wday['date']==pd.to_datetime('2024-12-26', format='%Y-%m-%d').date()) |
(car_r1_wday['date']==pd.to_datetime('2023-01-01', format='%Y-%m-%d').date()) |
(car_r1_wday['date']==pd.to_datetime('2023-02-06', format='%Y-%m-%d').date()) |
(car_r1_wday['date']==pd.to_datetime('2023-03-17', format='%Y-%m-%d').date()) |
(car_r1_wday['date']==pd.to_datetime('2023-04-10', format='%Y-%m-%d').date()) |
(car_r1_wday['date']==pd.to_datetime('2023-05-01', format='%Y-%m-%d').date()) |
(car_r1_wday['date']==pd.to_datetime('2023-06-05', format='%Y-%m-%d').date()) |
(car_r1_wday['date']==pd.to_datetime('2023-08-07', format='%Y-%m-%d').date()) |
(car_r1_wday['date']==pd.to_datetime('2023-10-30', format='%Y-%m-%d').date()) |
(car_r1_wday['date']==pd.to_datetime('2023-12-25', format='%Y-%m-%d').date()) |
(car_r1_wday['date']==pd.to_datetime('2023-12-26', format='%Y-%m-%d').date())
)]


hgv_r2_wday=hgv_r2_wday[~((hgv_r2_wday['date']==pd.to_datetime('2024-02-05', format='%Y-%m-%d').date()) |
(hgv_r2_wday['date']==pd.to_datetime('2024-01-01', format='%Y-%m-%d').date()) |
(hgv_r2_wday['date']==pd.to_datetime('2024-03-17', format='%Y-%m-%d').date()) |
(hgv_r2_wday['date']==pd.to_datetime('2024-04-01', format='%Y-%m-%d').date()) |
(hgv_r2_wday['date']==pd.to_datetime('2024-05-06', format='%Y-%m-%d').date()) |
(hgv_r2_wday['date']==pd.to_datetime('2024-06-03', format='%Y-%m-%d').date()) |
(hgv_r2_wday['date']==pd.to_datetime('2024-08-05', format='%Y-%m-%d').date()) |
(hgv_r2_wday['date']==pd.to_datetime('2024-10-28', format='%Y-%m-%d').date()) |
(hgv_r2_wday['date']==pd.to_datetime('2024-12-25', format='%Y-%m-%d').date()) |
(hgv_r2_wday['date']==pd.to_datetime('2024-12-26', format='%Y-%m-%d').date()) |
(hgv_r2_wday['date']==pd.to_datetime('2023-01-01', format='%Y-%m-%d').date()) |
(hgv_r2_wday['date']==pd.to_datetime('2023-02-06', format='%Y-%m-%d').date()) |
(hgv_r2_wday['date']==pd.to_datetime('2023-03-17', format='%Y-%m-%d').date()) |
(hgv_r2_wday['date']==pd.to_datetime('2023-04-10', format='%Y-%m-%d').date()) |
(hgv_r2_wday['date']==pd.to_datetime('2023-05-01', format='%Y-%m-%d').date()) |
(hgv_r2_wday['date']==pd.to_datetime('2023-06-05', format='%Y-%m-%d').date()) |
(hgv_r2_wday['date']==pd.to_datetime('2023-08-07', format='%Y-%m-%d').date()) |
(hgv_r2_wday['date']==pd.to_datetime('2023-10-30', format='%Y-%m-%d').date()) |
(hgv_r2_wday['date']==pd.to_datetime('2023-12-25', format='%Y-%m-%d').date()) |
(hgv_r2_wday['date']==pd.to_datetime('2023-12-26', format='%Y-%m-%d').date())
)]

# %%
car_r1_wday.reset_index(inplace=True)
car_r1_wday.drop(columns=['index'],axis=1, inplace=True)

hgv_r2_wday.reset_index(inplace=True)
hgv_r2_wday.drop(columns=['index'],axis=1, inplace=True)

# %%
hgv_r2_wday
# Out:
#        Unnamed: 0             datetime  value  hour        date  weekdays
# 0              24  2023-01-02 00:00:00    7.0     0  2023-01-02         0
# 1              25  2023-01-02 01:00:00    8.0     1  2023-01-02         0
# 2              26  2023-01-02 02:00:00    5.0     2  2023-01-02         0
# 3              27  2023-01-02 03:00:00    2.0     3  2023-01-02         0
# 4              28  2023-01-02 04:00:00    2.0     4  2023-01-02         0
# ...           ...                  ...    ...   ...         ...       ...
# 12091       17539  2024-12-31 19:00:00   16.0    19  2024-12-31         1
# 12092       17540  2024-12-31 20:00:00   15.0    20  2024-12-31         1
# 12093       17541  2024-12-31 21:00:00   12.0    21  2024-12-31         1
# 12094       17542  2024-12-31 22:00:00   11.0    22  2024-12-31         1
# 12095       17543  2024-12-31 23:00:00   13.0    23  2024-12-31         1
#
# [12096 rows x 6 columns]

# %%
from datetime import datetime
summer_break_start1= datetime.strptime("2023-07-01", "%Y-%m-%d").date()
summer_break_end1 = datetime.strptime("2023-08-25", "%Y-%m-%d").date()

summer_break_start2= datetime.strptime("2022-07-01", "%Y-%m-%d").date()
summer_break_end2 = datetime.strptime("2022-08-26", "%Y-%m-%d").date()

summer_break_start3= datetime.strptime("2024-07-01", "%Y-%m-%d").date()
summer_break_end3 = datetime.strptime("2024-08-30", "%Y-%m-%d").date()

###########################################################################

oct_break_start1= datetime.strptime("2023-10-30", "%Y-%m-%d").date()
oct_break_end1 = datetime.strptime("2023-11-03", "%Y-%m-%d").date()

oct_break_start2= datetime.strptime("2022-10-31", "%Y-%m-%d").date()
oct_break_end2 = datetime.strptime("2022-11-04", "%Y-%m-%d").date()

oct_break_start3= datetime.strptime("2024-10-28", "%Y-%m-%d").date()
oct_break_end3 = datetime.strptime("2024-11-01", "%Y-%m-%d").date()

###########################################################################

christmas_break_start1= datetime.strptime("2023-12-23", "%Y-%m-%d").date()
christmas_break_end1 = datetime.strptime("2024-01-07", "%Y-%m-%d").date()

christmas_break_start2= datetime.strptime("2022-01-01", "%Y-%m-%d").date()
christmas_break_end2 = datetime.strptime("2022-01-05", "%Y-%m-%d").date()

christmas_break_start3= datetime.strptime("2022-12-22", "%Y-%m-%d").date()
christmas_break_end3 = datetime.strptime("2023-01-04", "%Y-%m-%d").date()

christmas_break_start4= datetime.strptime("2024-12-21", "%Y-%m-%d").date()
christmas_break_end4 = datetime.strptime("2024-12-31", "%Y-%m-%d").date()

###########################################################################

feb_break_start1= datetime.strptime("2024-02-12", "%Y-%m-%d").date()
feb_break_end1 = datetime.strptime("2024-02-16", "%Y-%m-%d").date()

feb_break_start2= datetime.strptime("2023-02-13", "%Y-%m-%d").date()
feb_break_end2 = datetime.strptime("2023-02-17", "%Y-%m-%d").date()

feb_break_start3= datetime.strptime("2022-02-21", "%Y-%m-%d").date()
feb_break_end3 = datetime.strptime("2022-02-25", "%Y-%m-%d").date()


###########################################################################

easter_break_start1= datetime.strptime("2024-03-23", "%Y-%m-%d").date()
easter_break_end1 = datetime.strptime("2024-04-07", "%Y-%m-%d").date()

easter_break_start2= datetime.strptime("2023-04-01", "%Y-%m-%d").date()
easter_break_end2 = datetime.strptime("2023-04-16", "%Y-%m-%d").date()

easter_break_start3= datetime.strptime("2022-04-09", "%Y-%m-%d").date()
easter_break_end3 = datetime.strptime("2022-04-24", "%Y-%m-%d").date()

###########################################################################

summer_break=car_r1_wday[((car_r1_wday['date']>=summer_break_start1) & (car_r1_wday['date']<=summer_break_end1)) |
                                    ((car_r1_wday['date']>=summer_break_start2) & (car_r1_wday['date']<=summer_break_end2)) |
                                    ((car_r1_wday['date']>=summer_break_start3) & (car_r1_wday['date']<=summer_break_end3))]


oct_break=car_r1_wday[((car_r1_wday['date']>=oct_break_start1) & (car_r1_wday['date']<=oct_break_end1)) |
                                 ((car_r1_wday['date']>=oct_break_start2) & (car_r1_wday['date']<=oct_break_end2)) |
                                 ((car_r1_wday['date']>=oct_break_start3) & (car_r1_wday['date']<=oct_break_end3))]

christmas_break=car_r1_wday[((car_r1_wday['date']>=christmas_break_start1) & (car_r1_wday['date']<=christmas_break_end1)) |
                                       ((car_r1_wday['date']>=christmas_break_start2) & (car_r1_wday['date']<=christmas_break_end2)) |
                                       ((car_r1_wday['date']>=christmas_break_start3) & (car_r1_wday['date']<=christmas_break_end3)) |
                                       ((car_r1_wday['date']>=christmas_break_start4) & (car_r1_wday['date']<=christmas_break_end4))]

feb_break=car_r1_wday[((car_r1_wday['date']>=feb_break_start1) & (car_r1_wday['date']<=feb_break_end1)) |
                                 ((car_r1_wday['date']>=feb_break_start2) & (car_r1_wday['date']<=feb_break_end2)) |
                                 ((car_r1_wday['date']>=feb_break_start1) & (car_r1_wday['date']<=feb_break_end3))]


easter_break=car_r1_wday[((car_r1_wday['date']>=easter_break_start1) & (car_r1_wday['date']<=easter_break_end1)) |
                                    ((car_r1_wday['date']>=easter_break_start2) & (car_r1_wday['date']<=easter_break_end2)) |
                                    ((car_r1_wday['date']>=easter_break_start3) & (car_r1_wday['date']<=easter_break_end3)) ]

summer_break['Week_Type']='Summer Break'
oct_break['Week_Type']='October Mid Term Break'
christmas_break['Week_Type']='Christmas Break'
feb_break['Week_Type']='February Mid Term Break'
easter_break['Week_Type']='Easter Break'

term_breaks=pd.concat([summer_break,oct_break,christmas_break,feb_break,easter_break])

term_breaks
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_505036\2703037726.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summer_break['Week_Type']='Summer Break'
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_505036\2703037726.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oct_break['Week_Type']='October Mid Term Break'
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_505036\2703037726.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
from datetime import datetime
summer_break_start1= datetime.strptime("2023-07-01", "%Y-%m-%d").date()
summer_break_end1 = datetime.strptime("2023-08-25", "%Y-%m-%d").date()

summer_break_start2= datetime.strptime("2022-07-01", "%Y-%m-%d").date()
summer_break_end2 = datetime.strptime("2022-08-26", "%Y-%m-%d").date()

summer_break_start3= datetime.strptime("2024-07-01", "%Y-%m-%d").date()
summer_break_end3 = datetime.strptime("2024-08-30", "%Y-%m-%d").date()

###########################################################################

oct_break_start1= datetime.strptime("2023-10-30", "%Y-%m-%d").date()
oct_break_end1 = datetime.strptime("2023-11-03", "%Y-%m-%d").date()

oct_break_start2= datetime.strptime("2022-10-31", "%Y-%m-%d").date()
oct_break_end2 = datetime.strptime("2022-11-04", "%Y-%m-%d").date()

oct_break_start3= datetime.strptime("2024-10-28", "%Y-%m-%d").date()
oct_break_end3 = datetime.strptime("2024-11-01", "%Y-%m-%d").date()

###########################################################################

christmas_break_start1= datetime.strptime("2023-12-23", "%Y-%m-%d").date()
christmas_break_end1 = datetime.strptime("2024-01-07", "%Y-%m-%d").date()

christmas_break_start2= datetime.strptime("2022-01-01", "%Y-%m-%d").date()
christmas_break_end2 = datetime.strptime("2022-01-05", "%Y-%m-%d").date()

christmas_break_start3= datetime.strptime("2022-12-22", "%Y-%m-%d").date()
christmas_break_end3 = datetime.strptime("2023-01-04", "%Y-%m-%d").date()

christmas_break_start4= datetime.strptime("2024-12-21", "%Y-%m-%d").date()
christmas_break_end4 = datetime.strptime("2024-12-31", "%Y-%m-%d").date()

###########################################################################

feb_break_start1= datetime.strptime("2024-02-12", "%Y-%m-%d").date()
feb_break_end1 = datetime.strptime("2024-02-16", "%Y-%m-%d").date()

feb_break_start2= datetime.strptime("2023-02-13", "%Y-%m-%d").date()
feb_break_end2 = datetime.strptime("2023-02-17", "%Y-%m-%d").date()

feb_break_start3= datetime.strptime("2022-02-21", "%Y-%m-%d").date()
feb_break_end3 = datetime.strptime("2022-02-25", "%Y-%m-%d").date()


###########################################################################

easter_break_start1= datetime.strptime("2024-03-23", "%Y-%m-%d").date()
easter_break_end1 = datetime.strptime("2024-04-07", "%Y-%m-%d").date()

easter_break_start2= datetime.strptime("2023-04-01", "%Y-%m-%d").date()
easter_break_end2 = datetime.strptime("2023-04-16", "%Y-%m-%d").date()

easter_break_start3= datetime.strptime("2022-04-09", "%Y-%m-%d").date()
easter_break_end3 = datetime.strptime("2022-04-24", "%Y-%m-%d").date()

###########################################################################

summer_break=hgv_r2_wday[((hgv_r2_wday['date']>=summer_break_start1) & (hgv_r2_wday['date']<=summer_break_end1)) |
                                    ((hgv_r2_wday['date']>=summer_break_start2) & (hgv_r2_wday['date']<=summer_break_end2)) |
                                    ((hgv_r2_wday['date']>=summer_break_start3) & (hgv_r2_wday['date']<=summer_break_end3))]


oct_break=hgv_r2_wday[((hgv_r2_wday['date']>=oct_break_start1) & (hgv_r2_wday['date']<=oct_break_end1)) |
                                 ((hgv_r2_wday['date']>=oct_break_start2) & (hgv_r2_wday['date']<=oct_break_end2)) |
                                 ((hgv_r2_wday['date']>=oct_break_start3) & (hgv_r2_wday['date']<=oct_break_end3))]

christmas_break=hgv_r2_wday[((hgv_r2_wday['date']>=christmas_break_start1) & (hgv_r2_wday['date']<=christmas_break_end1)) |
                                       ((hgv_r2_wday['date']>=christmas_break_start2) & (hgv_r2_wday['date']<=christmas_break_end2)) |
                                       ((hgv_r2_wday['date']>=christmas_break_start3) & (hgv_r2_wday['date']<=christmas_break_end3)) |
                                       ((hgv_r2_wday['date']>=christmas_break_start4) & (hgv_r2_wday['date']<=christmas_break_end4))]

feb_break=hgv_r2_wday[((hgv_r2_wday['date']>=feb_break_start1) & (hgv_r2_wday['date']<=feb_break_end1)) |
                                 ((hgv_r2_wday['date']>=feb_break_start2) & (hgv_r2_wday['date']<=feb_break_end2)) |
                                 ((hgv_r2_wday['date']>=feb_break_start1) & (hgv_r2_wday['date']<=feb_break_end3))]


easter_break=hgv_r2_wday[((hgv_r2_wday['date']>=easter_break_start1) & (hgv_r2_wday['date']<=easter_break_end1)) |
                                    ((hgv_r2_wday['date']>=easter_break_start2) & (hgv_r2_wday['date']<=easter_break_end2)) |
                                    ((hgv_r2_wday['date']>=easter_break_start3) & (hgv_r2_wday['date']<=easter_break_end3)) ]

summer_break['Week_Type']='Summer Break'
oct_break['Week_Type']='October Mid Term Break'
christmas_break['Week_Type']='Christmas Break'
feb_break['Week_Type']='February Mid Term Break'
easter_break['Week_Type']='Easter Break'

term_breaks=pd.concat([summer_break,oct_break,christmas_break,feb_break,easter_break])

term_breaks
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_505036\1821724514.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summer_break['Week_Type']='Summer Break'
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_505036\1821724514.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oct_break['Week_Type']='October Mid Term Break'
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_505036\1821724514.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
school_days=car_r1_wday[
    ~(((car_r1_wday['date']>=summer_break_start1) & (car_r1_wday['date']<=summer_break_end1)) |
    ((car_r1_wday['date']>=summer_break_start2) & (car_r1_wday['date']<=summer_break_end2)) |
    ((car_r1_wday['date']>=summer_break_start3) & (car_r1_wday['date']<=summer_break_end3)) |
    ((car_r1_wday['date']>=oct_break_start1) & (car_r1_wday['date']<=oct_break_end1)) |
    ((car_r1_wday['date']>=oct_break_start2) & (car_r1_wday['date']<=oct_break_end2)) |
    ((car_r1_wday['date']>=oct_break_start3) & (car_r1_wday['date']<=oct_break_end3)) |
    ((car_r1_wday['date']>=christmas_break_start1) & (car_r1_wday['date']<=christmas_break_end1)) |
    ((car_r1_wday['date']>=christmas_break_start2) & (car_r1_wday['date']<=christmas_break_end2)) |
    ((car_r1_wday['date']>=christmas_break_start3) & (car_r1_wday['date']<=christmas_break_end3)) |
    ((car_r1_wday['date']>=christmas_break_start4) & (car_r1_wday['date']<=christmas_break_end4)) |
    ((car_r1_wday['date']>=feb_break_start1) & (car_r1_wday['date']<=feb_break_end1)) |
    ((car_r1_wday['date']>=feb_break_start2) & (car_r1_wday['date']<=feb_break_end2)) |
    ((car_r1_wday['date']>=feb_break_start1) & (car_r1_wday['date']<=feb_break_end3)) |
    ((car_r1_wday['date']>=easter_break_start1) & (car_r1_wday['date']<=easter_break_end1)) |
    ((car_r1_wday['date']>=easter_break_start2) & (car_r1_wday['date']<=easter_break_end2)) |
    ((car_r1_wday['date']>=easter_break_start3) & (car_r1_wday['date']<=easter_break_end3)) |
    (car_r1_wday['date']<=datetime.strptime("2021-12-31", "%Y-%m-%d").date()))
    ]

# %%
school_days=hgv_r2_wday[
    ~(((hgv_r2_wday['date']>=summer_break_start1) & (hgv_r2_wday['date']<=summer_break_end1)) |
    ((hgv_r2_wday['date']>=summer_break_start2) & (hgv_r2_wday['date']<=summer_break_end2)) |
    ((hgv_r2_wday['date']>=summer_break_start3) & (hgv_r2_wday['date']<=summer_break_end3)) |
    ((hgv_r2_wday['date']>=oct_break_start1) & (hgv_r2_wday['date']<=oct_break_end1)) |
    ((hgv_r2_wday['date']>=oct_break_start2) & (hgv_r2_wday['date']<=oct_break_end2)) |
    ((hgv_r2_wday['date']>=oct_break_start3) & (hgv_r2_wday['date']<=oct_break_end3)) |
    ((hgv_r2_wday['date']>=christmas_break_start1) & (hgv_r2_wday['date']<=christmas_break_end1)) |
    ((hgv_r2_wday['date']>=christmas_break_start2) & (hgv_r2_wday['date']<=christmas_break_end2)) |
    ((hgv_r2_wday['date']>=christmas_break_start3) & (hgv_r2_wday['date']<=christmas_break_end3)) |
    ((hgv_r2_wday['date']>=christmas_break_start4) & (hgv_r2_wday['date']<=christmas_break_end4)) |
    ((hgv_r2_wday['date']>=feb_break_start1) & (hgv_r2_wday['date']<=feb_break_end1)) |
    ((hgv_r2_wday['date']>=feb_break_start2) & (hgv_r2_wday['date']<=feb_break_end2)) |
    ((hgv_r2_wday['date']>=feb_break_start1) & (hgv_r2_wday['date']<=feb_break_end3)) |
    ((hgv_r2_wday['date']>=easter_break_start1) & (hgv_r2_wday['date']<=easter_break_end1)) |
    ((hgv_r2_wday['date']>=easter_break_start2) & (hgv_r2_wday['date']<=easter_break_end2)) |
    ((hgv_r2_wday['date']>=easter_break_start3) & (hgv_r2_wday['date']<=easter_break_end3)) |
    (hgv_r2_wday['date']<=datetime.strptime("2021-12-31", "%Y-%m-%d").date()))
    ]

# %%
school_days.reset_index(inplace=True)
school_days
# Out:
#       index  Unnamed: 0             datetime  value  hour        date  \
# 0        72          96  2023-01-05 00:00:00   40.0     0  2023-01-05
# 1        73          97  2023-01-05 01:00:00   22.0     1  2023-01-05
# 2        74          98  2023-01-05 02:00:00   21.0     2  2023-01-05
# 3        75          99  2023-01-05 03:00:00   13.0     3  2023-01-05
# 4        76         100  2023-01-05 04:00:00   15.0     4  2023-01-05
# ...     ...         ...                  ...    ...   ...         ...
# 8875  11971       17275  2024-12-20 19:00:00  640.0    19  2024-12-20
# 8876  11972       17276  2024-12-20 20:00:00  478.0    20  2024-12-20
# 8877  11973       17277  2024-12-20 21:00:00  378.0    21  2024-12-20
# 8878  11974       17278  2024-12-20 22:00:00  319.0    22  2024-12-20
# 8879  11975       17279  2024-12-20 23:00:00  310.0    23  2024-12-20
#
#       weekdays
# 0            3
# 1            3
# 2            3
# 3            3
# 4            3
# ...        ...
# ...

# %%
term_breaks.reset_index(inplace=True)

# %%
school_days.drop(columns=['index'], axis=1, inplace=True)
term_breaks.drop(columns=['index'], axis=1, inplace=True)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_505036\3515449360.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   school_days.drop(columns=['index'], axis=1, inplace=True)

# %%
school_days['Week_Type']='School Working Days'
school_days
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_505036\3230534533.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   school_days['Week_Type']='School Working Days'
#       Unnamed: 0             datetime  value  hour        date  weekdays  \
# 0             96  2023-01-05 00:00:00   40.0     0  2023-01-05         3
# 1             97  2023-01-05 01:00:00   22.0     1  2023-01-05         3
# 2             98  2023-01-05 02:00:00   21.0     2  2023-01-05         3
# 3             99  2023-01-05 03:00:00   13.0     3  2023-01-05         3
# 4            100  2023-01-05 04:00:00   15.0     4  2023-01-05         3
# ...          ...                  ...    ...   ...         ...       ...
# ...

# %%
term_breaks2=term_breaks[['datetime','value','hour','date']]
term_breaks2['Week_Type']='School Holiday'
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_505036\174865219.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   term_breaks2['Week_Type']='School Holiday'

# %%
term_breaks2
# Out:
#                  datetime  value  hour        date       Week_Type
# 0     2023-07-03 00:00:00   64.0     0  2023-07-03  School Holiday
# 1     2023-07-03 01:00:00   38.0     1  2023-07-03  School Holiday
# 2     2023-07-03 02:00:00   43.0     2  2023-07-03  School Holiday
# 3     2023-07-03 03:00:00   32.0     3  2023-07-03  School Holiday
# 4     2023-07-03 04:00:00   24.0     4  2023-07-03  School Holiday
# ...                   ...    ...   ...         ...             ...
# 3211  2024-04-05 19:00:00  508.0    19  2024-04-05  School Holiday
# 3212  2024-04-05 20:00:00  351.0    20  2024-04-05  School Holiday
# 3213  2024-04-05 21:00:00  272.0    21  2024-04-05  School Holiday
# 3214  2024-04-05 22:00:00  231.0    22  2024-04-05  School Holiday
# 3215  2024-04-05 23:00:00  188.0    23  2024-04-05  School Holiday
#
# [3216 rows x 5 columns]

# %%
################################### working days vs  break ######################################
comb_df=pd.concat([term_breaks2, school_days])

comb_df['datetime']=pd.to_datetime(comb_df['datetime'])
# how to sort a dataframe based on a column in python?
comb_df_sorted = comb_df.sort_values(by='datetime')
comb_df_sorted


comb_df_sorted.reset_index(inplace=True)
comb_df_sorted

comb_df_sorted['hour']=pd.to_datetime(comb_df_sorted['datetime']).dt.hour
agg_df_c1 = comb_df_sorted.groupby(["Week_Type", "hour"])["value"].agg(['mean', 'std', 'count']).reset_index()

agg_df_c1['sem'] = agg_df_c1['std'] / agg_df_c1['count']**0.5  # Standard error
agg_df_c1['ci95'] = agg_df_c1['sem'] * stats.t.ppf(0.975, df=agg_df_c1['count'] - 1)

pivot_mean = agg_df_c1.pivot(index='hour', columns='Week_Type', values='mean')
pivot_ci = agg_df_c1.pivot(index='hour', columns='Week_Type', values='ci95')


plt.figure(figsize=(12,5))
for week in pivot_mean.columns:
    plt.errorbar(pivot_mean.index,
                 pivot_mean[week],
                 yerr=pivot_ci[week],
                 fmt='-o',
                 label=week)
    
plt.title("Personal Vehicle Count on Carrigrohane to Cork City, Western Road (95% CI)")
plt.xlabel("Hour")
plt.ylabel("Traffic count")
plt.legend()
plt.ylim(0,2500)
plt.grid(True)
plt.tight_layout()

# %%
agg_df_c2['sem'] = agg_df_c2['std'] / agg_df_c2['count']**0.5  # Standard error
agg_df_c2['ci95'] = agg_df_c2['sem'] * stats.t.ppf(0.975, df=agg_df_c2['count'] - 1)

pivot_mean = agg_df_c2.pivot(index='hour', columns='week_type', values='mean')
pivot_ci = agg_df_c2.pivot(index='hour', columns='week_type', values='ci95')

plt.figure(figsize=(12,6))
for week in pivot_mean.columns:
    plt.errorbar(pivot_mean.index,
                 pivot_mean[week],
                 yerr=pivot_ci[week],
                 fmt='-o',
                 label=week)

plt.title("Goods Vehicle volume on Carrigrohane to Cork City, Western Road (95% CI)")
plt.xlabel("Hour")
plt.ylabel("Mean Traffic Volume")
plt.legend()
plt.grid(True)
plt.ylim((0,500))
plt.tight_layout()

plt.show()
